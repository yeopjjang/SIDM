# %%
# python
import sys
import os
import importlib
# columnar analysis
from coffea import processor
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema
import awkward as ak
from dask.distributed import Client
# local
sys.path.insert(1, os.path.join(sys.path[0], '../../..')) # fixme: there must be a better way to handle this...
from sidm.tools import ffschema, sidm_processor, utilities
# always reload local modules to pick up changes during development
importlib.reload(ffschema)
importlib.reload(sidm_processor)
importlib.reload(utilities)
# plotting
import matplotlib.pyplot as plt
utilities.set_plot_style()
# %matplotlib inline
from tqdm.notebook import tqdm

# %%
samples_4mu = [
    
    "4Mu_150GeV_0p25GeV_0p013mm",
    "4Mu_150GeV_0p25GeV_0p13mm",
    "4Mu_150GeV_0p25GeV_1p3mm",
    "4Mu_150GeV_0p25GeV_6p7mm",
    "4Mu_150GeV_0p25GeV_13p0mm",   
    
    "4Mu_150GeV_1p2GeV_0p064mm",
    "4Mu_150GeV_1p2GeV_0p64mm",
    "4Mu_150GeV_1p2GeV_6p4mm",
    "4Mu_150GeV_1p2GeV_32p0mm",
    "4Mu_150GeV_1p2GeV_64p0mm",
    
    "4Mu_150GeV_5p0GeV_0p27mm",
    "4Mu_150GeV_5p0GeV_2p7mm",
    "4Mu_150GeV_5p0GeV_27p0mm",
    "4Mu_150GeV_5p0GeV_130p0mm",
    "4Mu_150GeV_5p0GeV_270p0mm",
    
]

samples_bkg = [
    "TTJets",
]

# %%
# fileset_4mu = utilities.make_fileset(samples_4mu, "llpNanoAOD_v2", max_files=10, location_cfg="signal_v6.yaml")
# fileset_bkg = utilities.make_fileset(samples_bkg, "llpNanoAOD_v2", max_files=10, location_cfg="backgrounds.yaml")

fileset_4mu = utilities.make_fileset(samples_4mu, "llpNanoAOD_v2", location_cfg="signal_v6.yaml")
fileset_bkg = utilities.make_fileset(samples_bkg, "llpNanoAOD_v2", location_cfg="backgrounds.yaml")

fileset_4mu['TTJets'] = fileset_bkg['TTJets']

runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    #executor=processor.FuturesExecutor(),
    schema=NanoAODSchema,
#    maxchunks=10,
    skipbadfiles=True
)

channels = [
    "base",
]

p = sidm_processor.SidmProcessor(
    channels,
    ["base"],
)

output_4mu = runner.run(fileset_4mu, treename="Events", processor_instance=p)

out_4mu = output_4mu["out"]
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# /opt/conda/lib/python3.9/site-packages/awkward/_connect/_numpy.py:195: RuntimeWarning: divide by zero encountered
# in divide
#   result = getattr(ufunc, method)(
# /opt/conda/lib/python3.9/site-packages/awkward/_connect/_numpy.py:195: RuntimeWarning: invalid value encountered in
# divide
#   result = getattr(ufunc, method)(
# #--------------------------------------------------------------------------
# #                         FastJet release 3.4.0
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
samples_100_025 = [
    "TTJets",
    
    "4Mu_150GeV_0p25GeV_0p013mm",
    "4Mu_150GeV_0p25GeV_0p13mm",
    "4Mu_150GeV_0p25GeV_1p3mm",
    "4Mu_150GeV_0p25GeV_6p7mm",
    "4Mu_150GeV_0p25GeV_13p0mm",    
]

samples_100_125 = [
    "TTJets",
    
    "4Mu_150GeV_1p2GeV_0p064mm",
    "4Mu_150GeV_1p2GeV_0p64mm",
    "4Mu_150GeV_1p2GeV_6p4mm",
    "4Mu_150GeV_1p2GeV_32p0mm",
    "4Mu_150GeV_1p2GeV_64p0mm",
]

samples_100_5 = [
    "TTJets",
    
    "4Mu_150GeV_5p0GeV_0p27mm",
    "4Mu_150GeV_5p0GeV_2p7mm",
    "4Mu_150GeV_5p0GeV_27p0mm",
    "4Mu_150GeV_5p0GeV_130p0mm",
    "4Mu_150GeV_5p0GeV_270p0mm",
]

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=2, prop={'size': 18})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=2, prop={'size': 18})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=2, prop={'size': 18})

# %%
plt.subplots(3,2,figsize=(24,30))

plt.subplot(3,2,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(3,2,2)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["lj_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(3,2,3)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(3,2,4)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["lj_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(3,2,5)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

plt.subplot(3,2,6)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["lj_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(40,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=2, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=2, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=2, prop={'size': 16})

# %%
plt.subplots(3,2,figsize=(24,30))

plt.subplot(3,2,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(3,2,2)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["mu_lj_mu_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(3,2,3)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(3,2,4)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["mu_lj_mu_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(3,2,5)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

plt.subplot(3,2,6)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["mu_lj_mu_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ptRatio"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ptRatio"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ptRatio"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ERatio"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ERatio"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ERatio"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lep_fraction"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=2, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lep_fraction"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=2, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lep_fraction"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=2, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation2"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation2"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation2"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=2, prop={'size': 16})

# %%
for sample in samples_100_025:
    print(sample, "Total LJs", out_4mu[sample]["counters"]["0.4"]['base']['Total LJs'])
    print(sample, "Total Mu-LJs", out_4mu[sample]["counters"]["0.4"]['base']['Mu-LJs'])
    print(sample, "Total EGM-LJs", out_4mu[sample]["counters"]["0.4"]['base']['EGM-LJs'])
    print("")
    print(sample, "Total Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Total Matched-Jets'])
    print(sample, "Total Leading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Leading-Mu-Matched-Jets'])
    print(sample, "Total Subleading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Subleading-Mu-Matched-Jets'])
    print(sample, "Total EGM-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['EGM-Matched-Jets'])
    print("##############################")
    print("")
# Out:
# TTJets Total LJs 1825
# TTJets Total Mu-LJs 898
# TTJets Total EGM-LJs 927
#
# TTJets Total Matched-Jets 1813
# TTJets Total Leading-Mu-Matched-Jets 872
# TTJets Total Subleading-Mu-Matched-Jets 37
# TTJets Total EGM-Matched-Jets 867
# ##############################
#
# 4Mu_150GeV_0p25GeV_0p013mm Total LJs 3155
# 4Mu_150GeV_0p25GeV_0p013mm Total Mu-LJs 3148
# 4Mu_150GeV_0p25GeV_0p013mm Total EGM-LJs 7
#
# 4Mu_150GeV_0p25GeV_0p013mm Total Matched-Jets 3152
# 4Mu_150GeV_0p25GeV_0p013mm Total Leading-Mu-Matched-Jets 1576
# 4Mu_150GeV_0p25GeV_0p013mm Total Subleading-Mu-Matched-Jets 1572
# 4Mu_150GeV_0p25GeV_0p013mm Total EGM-Matched-Jets 7
# ##############################
#
# 4Mu_150GeV_0p25GeV_0p13mm Total LJs 3403
# 4Mu_150GeV_0p25GeV_0p13mm Total Mu-LJs 3395
# 4Mu_150GeV_0p25GeV_0p13mm Total EGM-LJs 8
#
# 4Mu_150GeV_0p25GeV_0p13mm Total Matched-Jets 3400
# 4Mu_150GeV_0p25GeV_0p13mm Total Leading-Mu-Matched-Jets 1700
# 4Mu_150GeV_0p25GeV_0p13mm Total Subleading-Mu-Matched-Jets 1695
# 4Mu_150GeV_0p25GeV_0p13mm Total EGM-Matched-Jets 8
# ##############################
#
# 4Mu_150GeV_0p25GeV_1p3mm Total LJs 3255
# 4Mu_150GeV_0p25GeV_1p3mm Total Mu-LJs 3249
# 4Mu_150GeV_0p25GeV_1p3mm Total EGM-LJs 6
#
# 4Mu_150GeV_0p25GeV_1p3mm Total Matched-Jets 3253
# 4Mu_150GeV_0p25GeV_1p3mm Total Leading-Mu-Matched-Jets 1626
# 4Mu_150GeV_0p25GeV_1p3mm Total Subleading-Mu-Matched-Jets 1622
# 4Mu_150GeV_0p25GeV_1p3mm Total EGM-Matched-Jets 6
# ##############################
#
# 4Mu_150GeV_0p25GeV_6p7mm Total LJs 3437
# 4Mu_150GeV_0p25GeV_6p7mm Total Mu-LJs 3430
# 4Mu_150GeV_0p25GeV_6p7mm Total EGM-LJs 7
#
# 4Mu_150GeV_0p25GeV_6p7mm Total Matched-Jets 3432
# 4Mu_150GeV_0p25GeV_6p7mm Total Leading-Mu-Matched-Jets 1716
# 4Mu_150GeV_0p25GeV_6p7mm Total Subleading-Mu-Matched-Jets 1712
# 4Mu_150GeV_0p25GeV_6p7mm Total EGM-Matched-Jets 7
# ##############################
#
# 4Mu_150GeV_0p25GeV_13p0mm Total LJs 3112
# 4Mu_150GeV_0p25GeV_13p0mm Total Mu-LJs 3104
# 4Mu_150GeV_0p25GeV_13p0mm Total EGM-LJs 8
#
# 4Mu_150GeV_0p25GeV_13p0mm Total Matched-Jets 3103
# 4Mu_150GeV_0p25GeV_13p0mm Total Leading-Mu-Matched-Jets 1551
# 4Mu_150GeV_0p25GeV_13p0mm Total Subleading-Mu-Matched-Jets 1546
# 4Mu_150GeV_0p25GeV_13p0mm Total EGM-Matched-Jets 8
# ##############################

# %%
for sample in samples_100_125:
    print(sample, "Total LJs", out_4mu[sample]["counters"]["0.4"]['base']['Total LJs'])
    print(sample, "Total Mu-LJs", out_4mu[sample]["counters"]["0.4"]['base']['Mu-LJs'])
    print(sample, "Total EGM-LJs", out_4mu[sample]["counters"]["0.4"]['base']['EGM-LJs'])
    print("")
    print(sample, "Total Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Total Matched-Jets'])
    print(sample, "Total Leading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Leading-Mu-Matched-Jets'])
    print(sample, "Total Subleading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Subleading-Mu-Matched-Jets'])
    print(sample, "Total EGM-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['EGM-Matched-Jets'])
    print("##############################")
    print("")
# Out:
# TTJets Total LJs 1825
# TTJets Total Mu-LJs 898
# TTJets Total EGM-LJs 927
#
# TTJets Total Matched-Jets 1813
# TTJets Total Leading-Mu-Matched-Jets 872
# TTJets Total Subleading-Mu-Matched-Jets 37
# TTJets Total EGM-Matched-Jets 867
# ##############################
#
# 4Mu_150GeV_1p2GeV_0p064mm Total LJs 93387
# 4Mu_150GeV_1p2GeV_0p064mm Total Mu-LJs 93370
# 4Mu_150GeV_1p2GeV_0p064mm Total EGM-LJs 17
#
# 4Mu_150GeV_1p2GeV_0p064mm Total Matched-Jets 93360
# 4Mu_150GeV_1p2GeV_0p064mm Total Leading-Mu-Matched-Jets 46678
# 4Mu_150GeV_1p2GeV_0p064mm Total Subleading-Mu-Matched-Jets 46680
# 4Mu_150GeV_1p2GeV_0p064mm Total EGM-Matched-Jets 17
# ##############################
#
# 4Mu_150GeV_1p2GeV_0p64mm Total LJs 95492
# 4Mu_150GeV_1p2GeV_0p64mm Total Mu-LJs 95470
# 4Mu_150GeV_1p2GeV_0p64mm Total EGM-LJs 22
#
# 4Mu_150GeV_1p2GeV_0p64mm Total Matched-Jets 95464
# 4Mu_150GeV_1p2GeV_0p64mm Total Leading-Mu-Matched-Jets 47733
# 4Mu_150GeV_1p2GeV_0p64mm Total Subleading-Mu-Matched-Jets 47725
# 4Mu_150GeV_1p2GeV_0p64mm Total EGM-Matched-Jets 22
# ##############################
#
# 4Mu_150GeV_1p2GeV_6p4mm Total LJs 101512
# 4Mu_150GeV_1p2GeV_6p4mm Total Mu-LJs 101491
# 4Mu_150GeV_1p2GeV_6p4mm Total EGM-LJs 21
#
# 4Mu_150GeV_1p2GeV_6p4mm Total Matched-Jets 101377
# 4Mu_150GeV_1p2GeV_6p4mm Total Leading-Mu-Matched-Jets 50701
# 4Mu_150GeV_1p2GeV_6p4mm Total Subleading-Mu-Matched-Jets 50674
# 4Mu_150GeV_1p2GeV_6p4mm Total EGM-Matched-Jets 21
# ##############################
#
# 4Mu_150GeV_1p2GeV_32p0mm Total LJs 51921
# 4Mu_150GeV_1p2GeV_32p0mm Total Mu-LJs 51910
# 4Mu_150GeV_1p2GeV_32p0mm Total EGM-LJs 11
#
# 4Mu_150GeV_1p2GeV_32p0mm Total Matched-Jets 51321
# 4Mu_150GeV_1p2GeV_32p0mm Total Leading-Mu-Matched-Jets 25643
# 4Mu_150GeV_1p2GeV_32p0mm Total Subleading-Mu-Matched-Jets 25668
# 4Mu_150GeV_1p2GeV_32p0mm Total EGM-Matched-Jets 11
# ##############################
#
# 4Mu_150GeV_1p2GeV_64p0mm Total LJs 27790
# 4Mu_150GeV_1p2GeV_64p0mm Total Mu-LJs 27780
# 4Mu_150GeV_1p2GeV_64p0mm Total EGM-LJs 10
#
# 4Mu_150GeV_1p2GeV_64p0mm Total Matched-Jets 27038
# 4Mu_150GeV_1p2GeV_64p0mm Total Leading-Mu-Matched-Jets 13524
# 4Mu_150GeV_1p2GeV_64p0mm Total Subleading-Mu-Matched-Jets 13507
# 4Mu_150GeV_1p2GeV_64p0mm Total EGM-Matched-Jets 10
# ##############################

# %%
for sample in samples_100_5:
    print(sample, "Total LJs", out_4mu[sample]["counters"]["0.4"]['base']['Total LJs'])
    print(sample, "Total Mu-LJs", out_4mu[sample]["counters"]["0.4"]['base']['Mu-LJs'])
    print(sample, "Total EGM-LJs", out_4mu[sample]["counters"]["0.4"]['base']['EGM-LJs'])
    print("")
    print(sample, "Total Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Total Matched-Jets'])
    print(sample, "Total Leading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Leading-Mu-Matched-Jets'])
    print(sample, "Total Subleading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Subleading-Mu-Matched-Jets'])
    print(sample, "Total EGM-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['EGM-Matched-Jets'])
    print("##############################")
    print("")
# Out:
# TTJets Total LJs 1825
# TTJets Total Mu-LJs 898
# TTJets Total EGM-LJs 927
#
# TTJets Total Matched-Jets 1813
# TTJets Total Leading-Mu-Matched-Jets 872
# TTJets Total Subleading-Mu-Matched-Jets 37
# TTJets Total EGM-Matched-Jets 867
# ##############################
#
# 4Mu_150GeV_5p0GeV_0p27mm Total LJs 82108
# 4Mu_150GeV_5p0GeV_0p27mm Total Mu-LJs 82090
# 4Mu_150GeV_5p0GeV_0p27mm Total EGM-LJs 18
#
# 4Mu_150GeV_5p0GeV_0p27mm Total Matched-Jets 82089
# 4Mu_150GeV_5p0GeV_0p27mm Total Leading-Mu-Matched-Jets 41046
# 4Mu_150GeV_5p0GeV_0p27mm Total Subleading-Mu-Matched-Jets 41039
# 4Mu_150GeV_5p0GeV_0p27mm Total EGM-Matched-Jets 18
# ##############################
#
# 4Mu_150GeV_5p0GeV_2p7mm Total LJs 98004
# 4Mu_150GeV_5p0GeV_2p7mm Total Mu-LJs 97985
# 4Mu_150GeV_5p0GeV_2p7mm Total EGM-LJs 19
#
# 4Mu_150GeV_5p0GeV_2p7mm Total Matched-Jets 97959
# 4Mu_150GeV_5p0GeV_2p7mm Total Leading-Mu-Matched-Jets 48975
# 4Mu_150GeV_5p0GeV_2p7mm Total Subleading-Mu-Matched-Jets 48982
# 4Mu_150GeV_5p0GeV_2p7mm Total EGM-Matched-Jets 19
# ##############################
#
# 4Mu_150GeV_5p0GeV_27p0mm Total LJs 53645
# 4Mu_150GeV_5p0GeV_27p0mm Total Mu-LJs 53632
# 4Mu_150GeV_5p0GeV_27p0mm Total EGM-LJs 13
#
# 4Mu_150GeV_5p0GeV_27p0mm Total Matched-Jets 53066
# 4Mu_150GeV_5p0GeV_27p0mm Total Leading-Mu-Matched-Jets 26521
# 4Mu_150GeV_5p0GeV_27p0mm Total Subleading-Mu-Matched-Jets 26535
# 4Mu_150GeV_5p0GeV_27p0mm Total EGM-Matched-Jets 13
# ##############################
#
# 4Mu_150GeV_5p0GeV_130p0mm Total LJs 10058
# 4Mu_150GeV_5p0GeV_130p0mm Total Mu-LJs 10047
# 4Mu_150GeV_5p0GeV_130p0mm Total EGM-LJs 11
#
# 4Mu_150GeV_5p0GeV_130p0mm Total Matched-Jets 9346
# 4Mu_150GeV_5p0GeV_130p0mm Total Leading-Mu-Matched-Jets 4650
# 4Mu_150GeV_5p0GeV_130p0mm Total Subleading-Mu-Matched-Jets 4687
# 4Mu_150GeV_5p0GeV_130p0mm Total EGM-Matched-Jets 11
# ##############################
#
# 4Mu_150GeV_5p0GeV_270p0mm Total LJs 2862
# 4Mu_150GeV_5p0GeV_270p0mm Total Mu-LJs 2858
# 4Mu_150GeV_5p0GeV_270p0mm Total EGM-LJs 4
#
# 4Mu_150GeV_5p0GeV_270p0mm Total Matched-Jets 2561
# 4Mu_150GeV_5p0GeV_270p0mm Total Leading-Mu-Matched-Jets 1279
# 4Mu_150GeV_5p0GeV_270p0mm Total Subleading-Mu-Matched-Jets 1278
# 4Mu_150GeV_5p0GeV_270p0mm Total EGM-Matched-Jets 4
# ##############################
