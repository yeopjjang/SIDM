# %%
# python
import sys
import os
import importlib
# columnar analysis
from coffea import processor
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema
import awkward as ak
from dask.distributed import Client
# local
sys.path.insert(1, os.path.join(sys.path[0], '../../..')) # fixme: there must be a better way to handle this...
from sidm.tools import ffschema, sidm_processor, utilities
# always reload local modules to pick up changes during development
importlib.reload(ffschema)
importlib.reload(sidm_processor)
importlib.reload(utilities)
# plotting
import matplotlib.pyplot as plt
utilities.set_plot_style()
# %matplotlib inline
from tqdm.notebook import tqdm

# %%
samples_4mu = [
    
    "4Mu_200GeV_0p25GeV_0p01mm",
    "4Mu_200GeV_0p25GeV_0p1mm",
    "4Mu_200GeV_0p25GeV_1p0mm",
    "4Mu_200GeV_0p25GeV_5p0mm",
    "4Mu_200GeV_0p25GeV_10p0mm",   
    
    "4Mu_200GeV_1p2GeV_0p048mm",
    "4Mu_200GeV_1p2GeV_0p48mm",
    "4Mu_200GeV_1p2GeV_4p8mm",
    "4Mu_200GeV_1p2GeV_24p0mm",
    "4Mu_200GeV_1p2GeV_48p0mm",
    
    "4Mu_200GeV_5p0GeV_0p2mm",
    "4Mu_200GeV_5p0GeV_2p0mm",
    "4Mu_200GeV_5p0GeV_20p0mm",
    "4Mu_200GeV_5p0GeV_100p0mm",
    "4Mu_200GeV_5p0GeV_200p0mm",
    
]

samples_bkg = [
    "TTJets",
]

# %%
# fileset_4mu = utilities.make_fileset(samples_4mu, "llpNanoAOD_v2", max_files=10, location_cfg="signal_v6.yaml")
# fileset_bkg = utilities.make_fileset(samples_bkg, "llpNanoAOD_v2", max_files=10, location_cfg="backgrounds.yaml")

fileset_4mu = utilities.make_fileset(samples_4mu, "llpNanoAOD_v2", location_cfg="signal_v6.yaml")
fileset_bkg = utilities.make_fileset(samples_bkg, "llpNanoAOD_v2", location_cfg="backgrounds.yaml")

fileset_4mu['TTJets'] = fileset_bkg['TTJets']

runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    #executor=processor.FuturesExecutor(),
    schema=NanoAODSchema,
#    maxchunks=10,
    skipbadfiles=True
)

channels = [
    "base",
]

p = sidm_processor.SidmProcessor(
    channels,
    ["base"],
)

output_4mu = runner.run(fileset_4mu, treename="Events", processor_instance=p)

out_4mu = output_4mu["out"]
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# /opt/conda/lib/python3.9/site-packages/awkward/_connect/_numpy.py:195: RuntimeWarning: divide by zero encountered
# in divide
#   result = getattr(ufunc, method)(
# /opt/conda/lib/python3.9/site-packages/awkward/_connect/_numpy.py:195: RuntimeWarning: invalid value encountered in
# divide
#   result = getattr(ufunc, method)(
# #--------------------------------------------------------------------------
# #                         FastJet release 3.4.0
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# Warning: a histogram with the name lj_matchedjet_pt could not be filled and will be skipped
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
samples_100_025 = [
    "TTJets",
    
    "4Mu_200GeV_0p25GeV_0p01mm",
    "4Mu_200GeV_0p25GeV_0p1mm",
    "4Mu_200GeV_0p25GeV_1p0mm",
    "4Mu_200GeV_0p25GeV_5p0mm",
    "4Mu_200GeV_0p25GeV_10p0mm", 
]

samples_100_125 = [
    "TTJets",
    
    "4Mu_200GeV_1p2GeV_0p048mm",
    "4Mu_200GeV_1p2GeV_0p48mm",
    "4Mu_200GeV_1p2GeV_4p8mm",
    "4Mu_200GeV_1p2GeV_24p0mm",
    "4Mu_200GeV_1p2GeV_48p0mm",
]

samples_100_5 = [
    "TTJets",
    
    "4Mu_200GeV_5p0GeV_0p2mm",
    "4Mu_200GeV_5p0GeV_2p0mm",
    "4Mu_200GeV_5p0GeV_20p0mm",
    "4Mu_200GeV_5p0GeV_100p0mm",
    "4Mu_200GeV_5p0GeV_200p0mm",
]

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=2, prop={'size': 18})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=2, prop={'size': 18})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=2, prop={'size': 18})

# %%
plt.subplots(3,2,figsize=(24,30))

plt.subplot(3,2,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(3,2,2)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["lj_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(3,2,3)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(3,2,4)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["lj_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(3,2,5)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["matchedjet_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

plt.subplot(3,2,6)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["lj_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(40,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=2, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=2, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_absdR"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=2, prop={'size': 16})

# %%
plt.subplots(3,2,figsize=(24,30))

plt.subplot(3,2,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(3,2,2)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["mu_lj_mu_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(3,2,3)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(3,2,4)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["mu_lj_mu_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(3,2,5)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["mu_matchedjet_mu_matchedjet_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

plt.subplot(3,2,6)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["mu_lj_mu_lj_invmass"][channels[0], :500j], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ptRatio"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ptRatio"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ptRatio"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ERatio"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ERatio"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lj_ERatio"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lep_fraction"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=2, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lep_fraction"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=2, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_lep_fraction"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=2, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=1, prop={'size': 16})

# %%
plt.subplots(1,3,figsize=(36,10))

plt.subplot(1,3,1)
for sample in samples_100_025:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation2"][channels[0], :], density=True)
plt.legend(samples_100_025, loc=1, prop={'size': 16})

plt.subplot(1,3,2)
for sample in samples_100_125:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation2"][channels[0], :], density=True)
plt.legend(samples_100_125, loc=1, prop={'size': 16})

plt.subplot(1,3,3)
for sample in samples_100_5:
    utilities.plot(out_4mu[sample]["hists"]["leading_mu_matchedjet_isolation2"][channels[0], :], density=True)
plt.legend(samples_100_5, loc=2, prop={'size': 16})

# %%
for sample in samples_100_025:
    print(sample, "Total LJs", out_4mu[sample]["counters"]["0.4"]['base']['Total LJs'])
    print(sample, "Total Mu-LJs", out_4mu[sample]["counters"]["0.4"]['base']['Mu-LJs'])
    print(sample, "Total EGM-LJs", out_4mu[sample]["counters"]["0.4"]['base']['EGM-LJs'])
    print("")
    print(sample, "Total Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Total Matched-Jets'])
    print(sample, "Total Leading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Leading-Mu-Matched-Jets'])
    print(sample, "Total Subleading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Subleading-Mu-Matched-Jets'])
    print(sample, "Total EGM-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['EGM-Matched-Jets'])
    print("##############################")
    print("")
# Out:
# TTJets Total LJs 1825
# TTJets Total Mu-LJs 898
# TTJets Total EGM-LJs 927
#
# TTJets Total Matched-Jets 1813
# TTJets Total Leading-Mu-Matched-Jets 872
# TTJets Total Subleading-Mu-Matched-Jets 37
# TTJets Total EGM-Matched-Jets 867
# ##############################
#
# 4Mu_200GeV_0p25GeV_0p01mm Total LJs 6042
# 4Mu_200GeV_0p25GeV_0p01mm Total Mu-LJs 6033
# 4Mu_200GeV_0p25GeV_0p01mm Total EGM-LJs 9
#
# 4Mu_200GeV_0p25GeV_0p01mm Total Matched-Jets 6036
# 4Mu_200GeV_0p25GeV_0p01mm Total Leading-Mu-Matched-Jets 3018
# 4Mu_200GeV_0p25GeV_0p01mm Total Subleading-Mu-Matched-Jets 3015
# 4Mu_200GeV_0p25GeV_0p01mm Total EGM-Matched-Jets 9
# ##############################
#
# 4Mu_200GeV_0p25GeV_0p1mm Total LJs 5934
# 4Mu_200GeV_0p25GeV_0p1mm Total Mu-LJs 5925
# 4Mu_200GeV_0p25GeV_0p1mm Total EGM-LJs 9
#
# 4Mu_200GeV_0p25GeV_0p1mm Total Matched-Jets 5925
# 4Mu_200GeV_0p25GeV_0p1mm Total Leading-Mu-Matched-Jets 2963
# 4Mu_200GeV_0p25GeV_0p1mm Total Subleading-Mu-Matched-Jets 2961
# 4Mu_200GeV_0p25GeV_0p1mm Total EGM-Matched-Jets 9
# ##############################
#
# 4Mu_200GeV_0p25GeV_1p0mm Total LJs 5933
# 4Mu_200GeV_0p25GeV_1p0mm Total Mu-LJs 5923
# 4Mu_200GeV_0p25GeV_1p0mm Total EGM-LJs 10
#
# 4Mu_200GeV_0p25GeV_1p0mm Total Matched-Jets 5926
# 4Mu_200GeV_0p25GeV_1p0mm Total Leading-Mu-Matched-Jets 2963
# 4Mu_200GeV_0p25GeV_1p0mm Total Subleading-Mu-Matched-Jets 2959
# 4Mu_200GeV_0p25GeV_1p0mm Total EGM-Matched-Jets 10
# ##############################
#
# 4Mu_200GeV_0p25GeV_5p0mm Total LJs 4482
# 4Mu_200GeV_0p25GeV_5p0mm Total Mu-LJs 4475
# 4Mu_200GeV_0p25GeV_5p0mm Total EGM-LJs 7
#
# 4Mu_200GeV_0p25GeV_5p0mm Total Matched-Jets 4468
# 4Mu_200GeV_0p25GeV_5p0mm Total Leading-Mu-Matched-Jets 2234
# 4Mu_200GeV_0p25GeV_5p0mm Total Subleading-Mu-Matched-Jets 2231
# 4Mu_200GeV_0p25GeV_5p0mm Total EGM-Matched-Jets 7
# ##############################
#
# 4Mu_200GeV_0p25GeV_10p0mm Total LJs 4475
# 4Mu_200GeV_0p25GeV_10p0mm Total Mu-LJs 4469
# 4Mu_200GeV_0p25GeV_10p0mm Total EGM-LJs 6
#
# 4Mu_200GeV_0p25GeV_10p0mm Total Matched-Jets 4465
# 4Mu_200GeV_0p25GeV_10p0mm Total Leading-Mu-Matched-Jets 2232
# 4Mu_200GeV_0p25GeV_10p0mm Total Subleading-Mu-Matched-Jets 2228
# 4Mu_200GeV_0p25GeV_10p0mm Total EGM-Matched-Jets 6
# ##############################

# %%
for sample in samples_100_125:
    print(sample, "Total LJs", out_4mu[sample]["counters"]["0.4"]['base']['Total LJs'])
    print(sample, "Total Mu-LJs", out_4mu[sample]["counters"]["0.4"]['base']['Mu-LJs'])
    print(sample, "Total EGM-LJs", out_4mu[sample]["counters"]["0.4"]['base']['EGM-LJs'])
    print("")
    print(sample, "Total Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Total Matched-Jets'])
    print(sample, "Total Leading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Leading-Mu-Matched-Jets'])
    print(sample, "Total Subleading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Subleading-Mu-Matched-Jets'])
    print(sample, "Total EGM-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['EGM-Matched-Jets'])
    print("##############################")
    print("")
# Out:
# TTJets Total LJs 1825
# TTJets Total Mu-LJs 898
# TTJets Total EGM-LJs 927
#
# TTJets Total Matched-Jets 1813
# TTJets Total Leading-Mu-Matched-Jets 872
# TTJets Total Subleading-Mu-Matched-Jets 37
# TTJets Total EGM-Matched-Jets 867
# ##############################
#
# 4Mu_200GeV_1p2GeV_0p048mm Total LJs 86354
# 4Mu_200GeV_1p2GeV_0p048mm Total Mu-LJs 86334
# 4Mu_200GeV_1p2GeV_0p048mm Total EGM-LJs 20
#
# 4Mu_200GeV_1p2GeV_0p048mm Total Matched-Jets 86334
# 4Mu_200GeV_1p2GeV_0p048mm Total Leading-Mu-Matched-Jets 43167
# 4Mu_200GeV_1p2GeV_0p048mm Total Subleading-Mu-Matched-Jets 43164
# 4Mu_200GeV_1p2GeV_0p048mm Total EGM-Matched-Jets 20
# ##############################
#
# 4Mu_200GeV_1p2GeV_0p48mm Total LJs 119543
# 4Mu_200GeV_1p2GeV_0p48mm Total Mu-LJs 119518
# 4Mu_200GeV_1p2GeV_0p48mm Total EGM-LJs 25
#
# 4Mu_200GeV_1p2GeV_0p48mm Total Matched-Jets 119508
# 4Mu_200GeV_1p2GeV_0p48mm Total Leading-Mu-Matched-Jets 59753
# 4Mu_200GeV_1p2GeV_0p48mm Total Subleading-Mu-Matched-Jets 59753
# 4Mu_200GeV_1p2GeV_0p48mm Total EGM-Matched-Jets 25
# ##############################
#
# 4Mu_200GeV_1p2GeV_4p8mm Total LJs 116126
# 4Mu_200GeV_1p2GeV_4p8mm Total Mu-LJs 116100
# 4Mu_200GeV_1p2GeV_4p8mm Total EGM-LJs 26
#
# 4Mu_200GeV_1p2GeV_4p8mm Total Matched-Jets 116003
# 4Mu_200GeV_1p2GeV_4p8mm Total Leading-Mu-Matched-Jets 58008
# 4Mu_200GeV_1p2GeV_4p8mm Total Subleading-Mu-Matched-Jets 57989
# 4Mu_200GeV_1p2GeV_4p8mm Total EGM-Matched-Jets 26
# ##############################
#
# 4Mu_200GeV_1p2GeV_24p0mm Total LJs 63929
# 4Mu_200GeV_1p2GeV_24p0mm Total Mu-LJs 63899
# 4Mu_200GeV_1p2GeV_24p0mm Total EGM-LJs 30
#
# 4Mu_200GeV_1p2GeV_24p0mm Total Matched-Jets 63289
# 4Mu_200GeV_1p2GeV_24p0mm Total Leading-Mu-Matched-Jets 31641
# 4Mu_200GeV_1p2GeV_24p0mm Total Subleading-Mu-Matched-Jets 31630
# 4Mu_200GeV_1p2GeV_24p0mm Total EGM-Matched-Jets 30
# ##############################
#
# 4Mu_200GeV_1p2GeV_48p0mm Total LJs 33904
# 4Mu_200GeV_1p2GeV_48p0mm Total Mu-LJs 33886
# 4Mu_200GeV_1p2GeV_48p0mm Total EGM-LJs 18
#
# 4Mu_200GeV_1p2GeV_48p0mm Total Matched-Jets 33123
# 4Mu_200GeV_1p2GeV_48p0mm Total Leading-Mu-Matched-Jets 16613
# 4Mu_200GeV_1p2GeV_48p0mm Total Subleading-Mu-Matched-Jets 16499
# 4Mu_200GeV_1p2GeV_48p0mm Total EGM-Matched-Jets 18
# ##############################

# %%
for sample in samples_100_5:
    print(sample, "Total LJs", out_4mu[sample]["counters"]["0.4"]['base']['Total LJs'])
    print(sample, "Total Mu-LJs", out_4mu[sample]["counters"]["0.4"]['base']['Mu-LJs'])
    print(sample, "Total EGM-LJs", out_4mu[sample]["counters"]["0.4"]['base']['EGM-LJs'])
    print("")
    print(sample, "Total Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Total Matched-Jets'])
    print(sample, "Total Leading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Leading-Mu-Matched-Jets'])
    print(sample, "Total Subleading-Mu-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['Subleading-Mu-Matched-Jets'])
    print(sample, "Total EGM-Matched-Jets", out_4mu[sample]["counters"]["0.4"]['base']['EGM-Matched-Jets'])
    print("##############################")
    print("")
# Out:
# TTJets Total LJs 1825
# TTJets Total Mu-LJs 898
# TTJets Total EGM-LJs 927
#
# TTJets Total Matched-Jets 1813
# TTJets Total Leading-Mu-Matched-Jets 872
# TTJets Total Subleading-Mu-Matched-Jets 37
# TTJets Total EGM-Matched-Jets 867
# ##############################
#
# 4Mu_200GeV_5p0GeV_0p2mm Total LJs 117922
# 4Mu_200GeV_5p0GeV_0p2mm Total Mu-LJs 117895
# 4Mu_200GeV_5p0GeV_0p2mm Total EGM-LJs 27
#
# 4Mu_200GeV_5p0GeV_0p2mm Total Matched-Jets 117901
# 4Mu_200GeV_5p0GeV_0p2mm Total Leading-Mu-Matched-Jets 58944
# 4Mu_200GeV_5p0GeV_0p2mm Total Subleading-Mu-Matched-Jets 58949
# 4Mu_200GeV_5p0GeV_0p2mm Total EGM-Matched-Jets 27
# ##############################
#
# 4Mu_200GeV_5p0GeV_2p0mm Total LJs 94597
# 4Mu_200GeV_5p0GeV_2p0mm Total Mu-LJs 94570
# 4Mu_200GeV_5p0GeV_2p0mm Total EGM-LJs 27
#
# 4Mu_200GeV_5p0GeV_2p0mm Total Matched-Jets 94562
# 4Mu_200GeV_5p0GeV_2p0mm Total Leading-Mu-Matched-Jets 47279
# 4Mu_200GeV_5p0GeV_2p0mm Total Subleading-Mu-Matched-Jets 47276
# 4Mu_200GeV_5p0GeV_2p0mm Total EGM-Matched-Jets 27
# ##############################
#
# 4Mu_200GeV_5p0GeV_20p0mm Total LJs 59834
# 4Mu_200GeV_5p0GeV_20p0mm Total Mu-LJs 59816
# 4Mu_200GeV_5p0GeV_20p0mm Total EGM-LJs 18
#
# 4Mu_200GeV_5p0GeV_20p0mm Total Matched-Jets 59297
# 4Mu_200GeV_5p0GeV_20p0mm Total Leading-Mu-Matched-Jets 29667
# 4Mu_200GeV_5p0GeV_20p0mm Total Subleading-Mu-Matched-Jets 29620
# 4Mu_200GeV_5p0GeV_20p0mm Total EGM-Matched-Jets 18
# ##############################
#
# 4Mu_200GeV_5p0GeV_100p0mm Total LJs 11980
# 4Mu_200GeV_5p0GeV_100p0mm Total Mu-LJs 11969
# 4Mu_200GeV_5p0GeV_100p0mm Total EGM-LJs 11
#
# 4Mu_200GeV_5p0GeV_100p0mm Total Matched-Jets 11231
# 4Mu_200GeV_5p0GeV_100p0mm Total Leading-Mu-Matched-Jets 5614
# 4Mu_200GeV_5p0GeV_100p0mm Total Subleading-Mu-Matched-Jets 5609
# 4Mu_200GeV_5p0GeV_100p0mm Total EGM-Matched-Jets 11
# ##############################
#
# 4Mu_200GeV_5p0GeV_200p0mm Total LJs 3943
# 4Mu_200GeV_5p0GeV_200p0mm Total Mu-LJs 3938
# 4Mu_200GeV_5p0GeV_200p0mm Total EGM-LJs 5
#
# 4Mu_200GeV_5p0GeV_200p0mm Total Matched-Jets 3579
# 4Mu_200GeV_5p0GeV_200p0mm Total Leading-Mu-Matched-Jets 1795
# 4Mu_200GeV_5p0GeV_200p0mm Total Subleading-Mu-Matched-Jets 1780
# 4Mu_200GeV_5p0GeV_200p0mm Total EGM-Matched-Jets 5
# ##############################
