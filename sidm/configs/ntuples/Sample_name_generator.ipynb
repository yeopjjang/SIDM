# %%
for i in range(0,199):
    print("      - skimmed_output2_{0}.root".format(i))
# Out:
#       - skimmed_output2_0.root
#       - skimmed_output2_1.root
#       - skimmed_output2_2.root
#       - skimmed_output2_3.root
#       - skimmed_output2_4.root
#       - skimmed_output2_5.root
#       - skimmed_output2_6.root
#       - skimmed_output2_7.root
#       - skimmed_output2_8.root
#       - skimmed_output2_9.root
#       - skimmed_output2_10.root
#       - skimmed_output2_11.root
#       - skimmed_output2_12.root
#       - skimmed_output2_13.root
#       - skimmed_output2_14.root
#       - skimmed_output2_15.root
#       - skimmed_output2_16.root
#       - skimmed_output2_17.root
#       - skimmed_output2_18.root
#       - skimmed_output2_19.root
#       - skimmed_output2_20.root
#       - skimmed_output2_21.root
#       - skimmed_output2_22.root
#       - skimmed_output2_23.root
#       - skimmed_output2_24.root
#       - skimmed_output2_25.root
#       - skimmed_output2_26.root
#       - skimmed_output2_27.root
#       - skimmed_output2_28.root
# ...
