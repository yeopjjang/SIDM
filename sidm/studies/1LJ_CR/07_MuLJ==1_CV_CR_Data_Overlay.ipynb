# %%
pip install -U mplhep
# Out:
# Requirement already satisfied: mplhep in /usr/local/lib/python3.12/site-packages (0.3.59)
# Collecting mplhep
#   Downloading mplhep-1.3.2-py3-none-any.whl.metadata (9.5 kB)
# Collecting matplotlib>=3.11.1 (from mplhep)
#   Using cached matplotlib-3.11.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (80 kB)
# Requirement already satisfied: mplhep-data>=0.0.4 in /usr/local/lib/python3.12/site-packages (from mplhep) (0.0.4)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/site-packages (from mplhep) (1.26.4)
# Requirement already satisfied: uhi>=0.2.0 in /usr/local/lib/python3.12/site-packages (from mplhep) (0.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (24.2)
# Requirement already satisfied: pillow>=9 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (10.3.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.11.1->mplhep) (1.17.0)
# Downloading mplhep-1.3.2-py3-none-any.whl (93 kB)
# Using cached matplotlib-3.11.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.0 MB)
# Installing collected packages: matplotlib, mplhep
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.3
#     Uninstalling matplotlib-3.10.3:
#       Successfully uninstalled matplotlib-3.10.3 0/2 [matplotlib]
#   Attempting uninstall: mplhep━━━━━━━━━━━━━━━━━━ 0/2 [matplotlib]
#     Found existing installation: mplhep 0.3.590m 0/2 [matplotlib]
#     Uninstalling mplhep-0.3.59:━━━━━━━━━━━━━ 0/2 [matplotlib]
#       Successfully uninstalled mplhep-0.3.59 0/2 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [mplhep]2m1/2 [mplhep]
# Successfully installed matplotlib-3.11.1 mplhep-1.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "numpy>=2.0,<2.3" --force-reinstall
# Out:
# Collecting numpy<2.3,>=2.0
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# python
import sys
import os
import importlib
# columnar analysis
from coffea import processor
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema
import awkward as ak
from dask.distributed import Client, performance_report
# local

sidm_path = str(os.getcwd()).split("/sidm")[0]
# sidm_path = str(sys.path[0]).split("/sidm")[0]
if sidm_path not in sys.path: sys.path.insert(1, sidm_path)
from sidm.tools import utilities, sidm_processor, scaleout, cutflow
from sidm.tools import llpnanoaodschema
# always reload local modules to pick up changes during development
importlib.reload(utilities)
importlib.reload(sidm_processor)
importlib.reload(scaleout)
# plotting
import matplotlib.pyplot as plt
utilities.set_plot_style()
# %matplotlib inline
from tqdm.notebook import tqdm
import coffea.util
import numpy as np
import mplhep as hep
import yaml
from sidm.tools.utilities import plot_data_mc
from pathlib import Path

# %%
# Load signal sample names from YAML files
yaml_file_path = "../../configs/ntuples/signal_2mu2e_v10.yaml"
with open(yaml_file_path, "r") as file:
    data = yaml.safe_load(file)

signals_2mu2e_all = list(
    data["llpNanoAOD_v2"]["samples"].keys()
)

yaml_file_path = "../../configs/ntuples/signal_4mu_v10.yaml"
with open(yaml_file_path, "r") as file:
    data = yaml.safe_load(file)

signals_4mu_all = list(
    data["llpNanoAOD_v2"]["samples"].keys()
)


# Combine all signal samples
signals_all = signals_2mu2e_all + signals_4mu_all


# Check whether an out dictionary already exists
try:
    out
    print(
        "The out dictionary already exists; "
        "will use what is saved in memory if possible"
    )
except NameError:
    print(
        "WARNING! No processor output stored in memory. "
        "Will load one coffea file for each sample."
    )
    out = {}

input_dir = Path("1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1")


# Load one merged coffea file for each signal point
for sample in signals_all:
    if sample in out:
        print(f"{sample} already found in memory; not loading file")
        continue

    input_file = input_dir / f"{sample}.coffea"
    print(f"Loading {input_file}")

    try:
        output = coffea.util.load(input_file)
    except FileNotFoundError:
        print(f"**** File not found: {input_file}")
        continue
    except Exception as error:
        print(f"**** Failed to load {input_file}: {error}")
        continue

    # Support the possible output structures:
    # output["out"][sample] or output[sample]
    if "out" in output and sample in output["out"]:
        out[sample] = output["out"][sample]
    elif sample in output:
        out[sample] = output[sample]
    else:
        print(
            f"**** Sample '{sample}' was not found inside "
            f"{input_file}"
        )
        print(f"Available top-level keys: {list(output.keys())}")
        continue

    print(f"Successfully loaded {sample}")
# Out:
# The out dictionary already exists; will use what is saved in memory if possible
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_0p25GeV_0p02mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_0p02mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_0p25GeV_0p2mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_0p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_0p25GeV_10p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_10p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_0p25GeV_20p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_20p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_1p2GeV_0p096mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_0p096mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_1p2GeV_0p96mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_0p96mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_1p2GeV_48p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_48p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_1p2GeV_96p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_96p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_5p0GeV_0p4mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_0p4mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_5p0GeV_4p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_4p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_5p0GeV_200mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_200mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_100GeV_5p0GeV_400mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_400mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_0p25GeV_0p013mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_0p013mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_0p25GeV_0p13mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_0p13mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_0p25GeV_1p3mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_1p3mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_0p25GeV_6p7mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_6p7mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_0p25GeV_13p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_13p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_1p2GeV_0p064mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_0p064mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_1p2GeV_0p64mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_0p64mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_1p2GeV_6p4mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_6p4mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_1p2GeV_32p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_32p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_1p2GeV_64p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_64p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_5p0GeV_0p27mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_0p27mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_5p0GeV_2p7mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_2p7mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_5p0GeV_27p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_27p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_5p0GeV_130p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_130p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_150GeV_5p0GeV_270p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_270p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_0p25GeV_0p01mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_0p01mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_0p25GeV_0p1mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_0p1mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_0p25GeV_1p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_1p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_0p25GeV_5p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_5p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_0p25GeV_10p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_10p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_1p2GeV_0p048mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_0p048mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_1p2GeV_0p48mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_0p48mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_1p2GeV_4p8mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_4p8mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_1p2GeV_24p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_24p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_1p2GeV_48p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_48p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_5p0GeV_0p2mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_0p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_5p0GeV_2p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_2p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_5p0GeV_20p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_20p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_5p0GeV_100p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_100p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_200GeV_5p0GeV_200p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_200p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_0p25GeV_0p004mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_0p004mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_0p25GeV_0p04mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_0p04mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_0p25GeV_0p4mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_0p4mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_0p25GeV_4p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_4p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_1p2GeV_0p019mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_0p019mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_1p2GeV_0p19mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_0p19mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_1p2GeV_1p9mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_1p9mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_1p2GeV_19p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_19p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_5p0GeV_0p08mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_0p08mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_5p0GeV_0p8mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_0p8mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_5p0GeV_8p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_8p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_500GeV_5p0GeV_80p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_80p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_0p25GeV_0p0025mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_0p0025mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_0p25GeV_0p025mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_0p025mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_0p25GeV_0p25mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_0p25mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_0p25GeV_1p2mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_1p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_0p25GeV_2p5mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_2p5mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_1p2GeV_0p012mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_0p012mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_1p2GeV_0p12mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_0p12mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_1p2GeV_1p2mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_1p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_1p2GeV_6p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_6p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_1p2GeV_12p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_12p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_5p0GeV_0p05mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_0p05mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_5p0GeV_0p5mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_0p5mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_5p0GeV_5p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_5p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_5p0GeV_25p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_25p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_800GeV_5p0GeV_50p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_50p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_0p25GeV_0p002mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_0p002mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_0p25GeV_0p02mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_0p02mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_0p25GeV_0p2mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_0p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_0p25GeV_1p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_1p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_1p2GeV_0p0096mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_0p0096mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_1p2GeV_0p096mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_0p096mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_1p2GeV_0p96mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_0p96mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_1p2GeV_4p8mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_4p8mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_5p0GeV_0p04mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_0p04mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_5p0GeV_0p4mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_0p4mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_5p0GeV_4p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_4p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_5p0GeV_20p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_20p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/2Mu2E_1000GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_0p25GeV_0p02mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_0p02mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_0p25GeV_0p2mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_0p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_0p25GeV_10p0mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_10p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_0p25GeV_20p0mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_20p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_1p2GeV_0p096mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_0p096mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_1p2GeV_0p96mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_0p96mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_1p2GeV_48p0mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_48p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_1p2GeV_96p0mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_96p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_5p0GeV_0p4mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_0p4mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_5p0GeV_4p0mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_4p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_5p0GeV_200mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_200mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_100GeV_5p0GeV_400mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_400mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_0p25GeV_0p013mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_0p013mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_0p25GeV_0p13mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_0p13mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_0p25GeV_1p3mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_1p3mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_0p25GeV_6p7mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_6p7mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_0p25GeV_13p0mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_13p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_1p2GeV_0p064mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_0p064mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_1p2GeV_0p64mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_0p64mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_1p2GeV_6p4mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_6p4mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_1p2GeV_32p0mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_32p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_1p2GeV_64p0mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_64p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_5p0GeV_0p27mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_0p27mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_5p0GeV_2p7mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_2p7mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_5p0GeV_27p0mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_27p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_5p0GeV_130p0mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_130p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_150GeV_5p0GeV_270p0mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_270p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_0p25GeV_0p01mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_0p01mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_0p25GeV_0p1mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_0p1mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_0p25GeV_1p0mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_1p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_0p25GeV_5p0mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_5p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_0p25GeV_10p0mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_10p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_1p2GeV_0p048mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_0p048mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_1p2GeV_0p48mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_0p48mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_1p2GeV_4p8mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_4p8mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_1p2GeV_24p0mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_24p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_1p2GeV_48p0mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_48p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_5p0GeV_0p2mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_0p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_5p0GeV_2p0mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_2p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_5p0GeV_20p0mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_20p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_5p0GeV_100p0mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_100p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_200GeV_5p0GeV_200p0mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_200p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_0p25GeV_0p004mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_0p004mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_0p25GeV_0p04mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_0p04mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_0p25GeV_0p4mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_0p4mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_0p25GeV_4p0mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_4p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_1p2GeV_0p019mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_0p019mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_1p2GeV_0p19mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_0p19mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_1p2GeV_1p9mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_1p9mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_1p2GeV_19p0mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_19p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_5p0GeV_0p08mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_0p08mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_5p0GeV_0p8mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_0p8mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_5p0GeV_8p0mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_8p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_500GeV_5p0GeV_80p0mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_80p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_0p25GeV_0p0025mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_0p0025mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_0p25GeV_0p025mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_0p025mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_0p25GeV_0p25mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_0p25mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_0p25GeV_1p2mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_1p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_0p25GeV_2p5mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_2p5mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_1p2GeV_0p012mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_0p012mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_1p2GeV_0p12mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_0p12mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_1p2GeV_1p2mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_1p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_1p2GeV_6p0mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_6p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_1p2GeV_12p0mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_12p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_5p0GeV_0p05mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_0p05mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_5p0GeV_0p5mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_0p5mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_5p0GeV_5p0mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_5p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_5p0GeV_25p0mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_25p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_800GeV_5p0GeV_50p0mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_50p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_0p25GeV_0p002mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_0p002mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_0p25GeV_0p02mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_0p02mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_0p25GeV_0p2mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_0p2mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_0p25GeV_1p0mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_1p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_1p2GeV_0p0096mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_0p0096mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_1p2GeV_0p096mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_0p096mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_1p2GeV_0p96mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_0p96mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_1p2GeV_4p8mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_4p8mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_5p0GeV_0p04mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_0p04mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_5p0GeV_0p4mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_0p4mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_5p0GeV_4p0mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_4p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_5p0GeV_20p0mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_20p0mm
# Loading 1LJ_CR_cosmic_veto_v1_signal_full_merged_samples_v1/4Mu_1000GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_40p0mm

# %%
samples_bkg = [
    "TTJets",
    "QCD_Pt15To20",
    "QCD_Pt20To30",
    "QCD_Pt30To50",
    "QCD_Pt50To80",
    "QCD_Pt80To120", 
    "QCD_Pt120To170",
    "QCD_Pt170To300", 
    "QCD_Pt300To470",
    "QCD_Pt470To600", 
    "QCD_Pt600To800", 
    "QCD_Pt800To1000",
    "QCD_Pt1000", 
    "DYJetsToLL_M10to50",
    "DYJetsToLL_M50", 
    "WW",
    "WZ",
    "ZZ",
]

samples_data= [ 
    "DoubleMuon_2018A_0",
    "DoubleMuon_2018A_1",
    "DoubleMuon_2018A_2",

    "DoubleMuon_2018B_0",
    "DoubleMuon_2018B_1",
    "DoubleMuon_2018B_2",
    "DoubleMuon_2018B_3",
    "DoubleMuon_2018B_4",
    "DoubleMuon_2018B_5",
    "DoubleMuon_2018B_6",
    "DoubleMuon_2018B_7",
    "DoubleMuon_2018B_8",
    "DoubleMuon_2018B_9",
    "DoubleMuon_2018B_10",
    "DoubleMuon_2018B_11",
    "DoubleMuon_2018B_12",
    "DoubleMuon_2018B_13",
    
    "DoubleMuon_2018C",

    "DoubleMuon_2018D_0",
    "DoubleMuon_2018D_1",
    "DoubleMuon_2018D_2",
    "DoubleMuon_2018D_3",
    "DoubleMuon_2018D_4",
    "DoubleMuon_2018D_5",
    "DoubleMuon_2018D_6",
    "DoubleMuon_2018D_7",
    "DoubleMuon_2018D_8",
    "DoubleMuon_2018D_9",
    "DoubleMuon_2018D_10",
    "DoubleMuon_2018D_11",
    "DoubleMuon_2018D_12",
    "DoubleMuon_2018D_13",
    "DoubleMuon_2018D_14",
    "DoubleMuon_2018D_15",
    "DoubleMuon_2018D_16",
    "DoubleMuon_2018D_17",
    "DoubleMuon_2018D_18",
    "DoubleMuon_2018D_19",
    "DoubleMuon_2018D_20",
    "DoubleMuon_2018D_21",
    "DoubleMuon_2018D_22",
    "DoubleMuon_2018D_23",
    "DoubleMuon_2018D_24",
    "DoubleMuon_2018D_25",
    "DoubleMuon_2018D_26",
    "DoubleMuon_2018D_27",
    "DoubleMuon_2018D_28",
    "DoubleMuon_2018D_29",
    "DoubleMuon_2018D_30",
    "DoubleMuon_2018D_31",
    "DoubleMuon_2018D_32",
    "DoubleMuon_2018D_33",
    "DoubleMuon_2018D_34",
    "DoubleMuon_2018D_35",
    "DoubleMuon_2018D_36",
    "DoubleMuon_2018D_37",
    "DoubleMuon_2018D_38",
    "DoubleMuon_2018D_39",
    "DoubleMuon_2018D_40",
    "DoubleMuon_2018D_41",
    "DoubleMuon_2018D_42",
    "DoubleMuon_2018D_43",
    "DoubleMuon_2018D_44",
    "DoubleMuon_2018D_45",
    "DoubleMuon_2018D_46",
    "DoubleMuon_2018D_47",
    "DoubleMuon_2018D_48",
    "DoubleMuon_2018D_49",
]

# %%
#First check if there is already an out dictionary
try:
    out
    print("The _out_ dictionary already exists; will use what is saved in memory if possible")
except NameError:
    print("WARNING! No processor output stored in the kernel's memory. Will try to load pickled coffea file for each sample instead")
    out = {}

#For each sample, try to use the data in memory if possible; if not try to load the file
#If those both fail, then raise an error and skip it
for sample in samples_bkg:
    if sample in out:
        print(f"{sample} already found in memory; not loading file")
    else:
        print(f"Loading file for sample {sample}")
        filename = sample + ".coffea"
        try: 
            output = coffea.util.load("1LJ_CR_cosmic_veto_v1_bkg_full_merged_samples_v1/"+filename)
            print("Successfully opened file")        
            out[sample] = output["out"][sample]
            # out[sample] = output["out"][sample.removesuffix("_part1")]
        except Exception:
            out[sample] = output[sample]
            # print("**** ERROR! File not found. Check the file name, or run the processor again and save the output to a pickle file using coffea.util.save")
# Out:
# The _out_ dictionary already exists; will use what is saved in memory if possible
# Loading file for sample TTJets
# Successfully opened file
# Loading file for sample QCD_Pt15To20
# Successfully opened file
# Loading file for sample QCD_Pt20To30
# Successfully opened file
# Loading file for sample QCD_Pt30To50
# Successfully opened file
# Loading file for sample QCD_Pt50To80
# Successfully opened file
# Loading file for sample QCD_Pt80To120
# Successfully opened file
# Loading file for sample QCD_Pt120To170
# Successfully opened file
# Loading file for sample QCD_Pt170To300
# Successfully opened file
# Loading file for sample QCD_Pt300To470
# Successfully opened file
# Loading file for sample QCD_Pt470To600
# Successfully opened file
# Loading file for sample QCD_Pt600To800
# Successfully opened file
# Loading file for sample QCD_Pt800To1000
# Successfully opened file
# Loading file for sample QCD_Pt1000
# Successfully opened file
# Loading file for sample DYJetsToLL_M10to50
# Successfully opened file
# Loading file for sample DYJetsToLL_M50
# Successfully opened file
# Loading file for sample WW
# Successfully opened file
# Loading file for sample WZ
# Successfully opened file
# Loading file for sample ZZ
# Successfully opened file

# %%
#First check if there is already an out dictionary
try:
    out_data
    print("The _out_ dictionary already exists; will use what is saved in memory if possible")
except NameError:
    print("WARNING! No processor output stored in the kernel's memory. Will try to load pickled coffea file for each sample instead")
    out_data = {}

#For each sample, try to use the data in memory if possible; if not try to load the file
#If those both fail, then raise an error and skip it
for data in samples_data:
    if data in out_data:
        print(f"{data} already found in memory; not loading file")
    else:
        print(f"Loading file for data {data}")
        filename = data + ".coffea"
        try: 
            output = coffea.util.load("1LJ_CR_cosmic_veto_v1_data_full_merged_samples_v1/"+filename)
            print("Successfully opened file")        
            out_data[data] = output["out"][data]
            # out[sample] = output["out"][sample.removesuffix("_part1")]
        except Exception:
            out_data[data] = output[data]
            # print("**** ERROR! File not found. Check the file name, or run the processor again and save the output to a pickle file using coffea.util.save")
# Out:
# WARNING! No processor output stored in the kernel's memory. Will try to load pickled coffea file for each sample instead
# Loading file for data DoubleMuon_2018A_0
# Successfully opened file
# Loading file for data DoubleMuon_2018A_1
# Successfully opened file
# Loading file for data DoubleMuon_2018A_2
# Successfully opened file
# Loading file for data DoubleMuon_2018B_0
# Successfully opened file
# Loading file for data DoubleMuon_2018B_1
# Successfully opened file
# Loading file for data DoubleMuon_2018B_2
# Successfully opened file
# Loading file for data DoubleMuon_2018B_3
# Successfully opened file
# Loading file for data DoubleMuon_2018B_4
# Successfully opened file
# Loading file for data DoubleMuon_2018B_5
# Successfully opened file
# Loading file for data DoubleMuon_2018B_6
# Successfully opened file
# Loading file for data DoubleMuon_2018B_7
# Successfully opened file
# Loading file for data DoubleMuon_2018B_8
# Successfully opened file
# Loading file for data DoubleMuon_2018B_9
# Successfully opened file
# Loading file for data DoubleMuon_2018B_10
# Successfully opened file
# Loading file for data DoubleMuon_2018B_11
# Successfully opened file
# Loading file for data DoubleMuon_2018B_12
# Successfully opened file
# Loading file for data DoubleMuon_2018B_13
# Successfully opened file
# Loading file for data DoubleMuon_2018C
# Successfully opened file
# Loading file for data DoubleMuon_2018D_0
# Successfully opened file
# Loading file for data DoubleMuon_2018D_1
# Successfully opened file
# Loading file for data DoubleMuon_2018D_2
# Successfully opened file
# Loading file for data DoubleMuon_2018D_3
# Successfully opened file
# Loading file for data DoubleMuon_2018D_4
# Successfully opened file
# Loading file for data DoubleMuon_2018D_5
# Successfully opened file
# Loading file for data DoubleMuon_2018D_6
# Successfully opened file
# Loading file for data DoubleMuon_2018D_7
# Successfully opened file
# Loading file for data DoubleMuon_2018D_8
# Successfully opened file
# Loading file for data DoubleMuon_2018D_9
# Successfully opened file
# Loading file for data DoubleMuon_2018D_10
# Successfully opened file
# Loading file for data DoubleMuon_2018D_11
# Successfully opened file
# Loading file for data DoubleMuon_2018D_12
# Successfully opened file
# Loading file for data DoubleMuon_2018D_13
# Successfully opened file
# Loading file for data DoubleMuon_2018D_14
# Successfully opened file
# Loading file for data DoubleMuon_2018D_15
# Successfully opened file
# Loading file for data DoubleMuon_2018D_16
# Successfully opened file
# Loading file for data DoubleMuon_2018D_17
# Successfully opened file
# Loading file for data DoubleMuon_2018D_18
# Successfully opened file
# Loading file for data DoubleMuon_2018D_19
# Successfully opened file
# Loading file for data DoubleMuon_2018D_20
# Successfully opened file
# Loading file for data DoubleMuon_2018D_21
# Successfully opened file
# Loading file for data DoubleMuon_2018D_22
# Successfully opened file
# Loading file for data DoubleMuon_2018D_23
# Successfully opened file
# Loading file for data DoubleMuon_2018D_24
# Successfully opened file
# Loading file for data DoubleMuon_2018D_25
# Successfully opened file
# Loading file for data DoubleMuon_2018D_26
# Successfully opened file
# Loading file for data DoubleMuon_2018D_27
# Successfully opened file
# Loading file for data DoubleMuon_2018D_28
# Successfully opened file
# Loading file for data DoubleMuon_2018D_29
# Successfully opened file
# Loading file for data DoubleMuon_2018D_30
# Successfully opened file
# Loading file for data DoubleMuon_2018D_31
# Successfully opened file
# Loading file for data DoubleMuon_2018D_32
# Successfully opened file
# Loading file for data DoubleMuon_2018D_33
# Successfully opened file
# Loading file for data DoubleMuon_2018D_34
# Successfully opened file
# Loading file for data DoubleMuon_2018D_35
# Successfully opened file
# Loading file for data DoubleMuon_2018D_36
# Successfully opened file
# Loading file for data DoubleMuon_2018D_37
# Successfully opened file
# Loading file for data DoubleMuon_2018D_38
# Successfully opened file
# Loading file for data DoubleMuon_2018D_39
# Successfully opened file
# Loading file for data DoubleMuon_2018D_40
# Successfully opened file
# Loading file for data DoubleMuon_2018D_41
# Successfully opened file
# Loading file for data DoubleMuon_2018D_42
# Successfully opened file
# Loading file for data DoubleMuon_2018D_43
# Successfully opened file
# Loading file for data DoubleMuon_2018D_44
# Successfully opened file
# Loading file for data DoubleMuon_2018D_45
# Successfully opened file
# Loading file for data DoubleMuon_2018D_46
# Successfully opened file
# Loading file for data DoubleMuon_2018D_47
# Successfully opened file
# Loading file for data DoubleMuon_2018D_48
# Successfully opened file
# Loading file for data DoubleMuon_2018D_49
# Successfully opened file

# %%
channels = [
    "data_control_region_1muLj_spread_cosAlpha_mu_veto",
]

# %%
QCD = [
    "QCD_Pt15To20",
    "QCD_Pt20To30",
    "QCD_Pt30To50",
    "QCD_Pt50To80",
    "QCD_Pt80To120",
    "QCD_Pt120To170",
    "QCD_Pt170To300",
    "QCD_Pt300To470",
    "QCD_Pt470To600",
    "QCD_Pt600To800",
    "QCD_Pt800To1000",
    "QCD_Pt1000",
]

DY = [
    "DYJetsToLL_M10to50",
    "DYJetsToLL_M50",
]

TT = ["TTJets"]

Diboson = [
    "WW",
    "WZ",
    "ZZ"]

# %%
backgrounds = {
    "Diboson": Diboson,
    "TT": TT,
    "DY": DY,
    "QCD": QCD,
}

background_colors = {
    "Diboson": "#717581",
    "TT": "#3f90da",
    "DY": "#b9ac70",
    "QCD": "#832db6",
}
signal_maps = {
    "2Mu2E": ["2Mu2E_100GeV_5p0GeV_40p0mm", "2Mu2E_500GeV_1p2GeV_1p9mm", "2Mu2E_1000GeV_0p25GeV_0p2mm"],
    "4Mu": ["4Mu_100GeV_5p0GeV_40p0mm", "4Mu_500GeV_1p2GeV_1p9mm", "4Mu_1000GeV_0p25GeV_0p2mm"],
}

signal_colors = ["r", "orange", "gold", "lime", "cyan", "magenta"]

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    mc_lumi_scale=1,
    logy=True,
    variable="muon_pt",
    xlabel=r"Muon pT",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="muon_eta",
    xlabel=r"Muon $\eta$",
    target_bins=25,
    rebin_threshold=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="muon_phi",
    xlabel=r"Muon $\phi$",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="muon_dxy_lowRange",
    xlabel=r"Muon dxy",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsaMuon_pt",
    xlabel=r"DSA Muon pT",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsaMuon_eta",
    xlabel=r"DSA Muon $\eta$",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsaMuon_phi",
    xlabel=r"DSA Muon $\phi$",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsaMuon_dxy",
    xlabel=r"DSA Muon dxy",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsaMuon_dz",
    xlabel=r"DSA Muon dz",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsaMu_dsaMu_cosAlpha",
    xlabel=r"CosAlpha(DSA $\mu$, DSA $\mu$)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_n",
    xlabel=r"Number of Mu-LJ",
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_pt",
    xlabel=r"$\mu$-type Lepton Jet $p_T$ (GeV)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="pfmu_lj_pt",
    xlabel=r"PF $\mu$-type Lepton Jet $p_T$ (GeV)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsamu_lj_pt",
    xlabel=r"DSA $\mu$-type Lepton Jet $p_T$ (GeV)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_eta",
    xlabel=r"$\mu$-type Lepton Jet $\eta$",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_phi",
    xlabel=r"$\mu$-type Lepton Jet $\phi$",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_mass",
    xlabel=r"$\mu$-type Lepton Jet mass",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_muonN",
    xlabel=r"$\mu$-type Lepton Jet muon_n",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_pfMu_n",
    xlabel=r"$\mu$-type Lepton Jet PF muon_n",
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_dsaMu_n",
    xlabel=r"$\mu$-type Lepton Jet DSA muon_n",
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_muon_pt",
    xlabel=r"$\mu$- type LJ $\mu$ pT (GeV)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_pfMuon_pt",
    xlabel=r"$\mu$- type LJ PF $\mu$ pT (GeV)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_dsaMuon_pt",
    xlabel=r"$\mu$- type LJ DSA $\mu$ pT (GeV)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_muon_dxy",
    xlabel=r"$\mu$- type LJ $\mu$ dxy (cm)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_pfMuon_dxy",
    xlabel=r"$\mu$- type LJ PF $\mu$ dxy (cm)",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_dsaMuon_dxy",
    xlabel=r"$\mu$- type LJ DSA $\mu$ dxy (cm)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_dsaMuon_dz",
    xlabel=r"$\mu$- type LJ DSA $\mu$ dz (cm)",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_e",
    xlabel=r"Mu LJ Energy [GeV]",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="pfmu_lj_e",
    xlabel=r"PF Mu LJ Energy [GeV]",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsamu_lj_e",
    xlabel=r"DSA Mu LJ Energy [GeV]",
    target_bins=25,
    plot_label="Work in Progress"
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_lj_iso",
    xlabel=r"Mu-LJ Isolation",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="pfmu_lj_iso",
    xlabel=r"PF Mu-LJ Isolation",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsamu_lj_iso",
    xlabel=r"DSA Mu-LJ Isolation",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_matched_jet_n",
    xlabel=r"Number of Mu Matched Jet",
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_matched_jet_pt",
    xlabel=r"Mu Matched Jet PT [GeV]",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="pfmu_matched_jet_pt",
    xlabel=r"PF Mu Matched Jet PT [GeV]",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsamu_matched_jet_pt",
    xlabel=r"DSA Mu Matched Jet PT [GeV]",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_matched_jet_e",
    xlabel=r"Mu Matched Jet Energy [GeV]",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="pfmu_matched_jet_e",
    xlabel=r"PF Mu Matched Jet Energy [GeV]",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsamu_matched_jet_e",
    xlabel=r"DSA Mu Matched Jet Energy [GeV]",
    target_bins=25,
    plot_label="Work in Progress",
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_matched_jet_lepfraction",
    xlabel=r"Mu Matched Jet Lepton Fraction",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="pfmu_matched_jet_lepfraction",
    xlabel=r"PF Mu Matched Jet Lepton Fraction",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsamu_matched_jet_lepfraction",
    xlabel=r"DSA Mu Matched Jet Lepton Fraction",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_matched_jet_lj_dR",
    xlabel=r"dR(Mu-LJ, Mu-Matched Jet)",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,    
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="pfmu_matched_jet_lj_dR",
    xlabel=r"dR(PF Mu-LJ, PF Mu-Matched Jet)",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,   
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsamu_matched_jet_lj_dR",
    xlabel=r"dR(DSA Mu-LJ, DSA Mu-Matched Jet)",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,   
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dpt_mu_matched_jet_lj_large",
    xlabel=r"|Mu Matched Jet $p_{T}$ - Mu LJ $p_{T}$|",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,   
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dpt_pfmu_matched_jet_lj_large",
    xlabel=r"|PF Mu Matched Jet $p_{T}$ - PF Mu LJ $p_{T}$|",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,   
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dpt_dsamu_matched_jet_lj_large",
    xlabel=r"|DSA Mu Matched Jet $p_{T}$ - DSA Mu LJ $p_{T}$|",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,   
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="mu_mj_lj_Eratio",
    xlabel=r"Mu-type $E_{Matched Jet} / E_{LJ}$",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,   
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="pfmu_mj_lj_Eratio",
    xlabel=r"PF Mu-type $E_{Matched Jet} / E_{LJ}$",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,   
)

# %%
fig, ax_main, ax_ratio = plot_data_mc(
    out=out,
    out_data=out_data,
    channel=channels[0],
    data_samples=samples_data,
    backgrounds=backgrounds,
    background_colors=background_colors,
    signal_maps=signal_maps,
    year=2018,
    lumi=59.83,
    logy=True,
    variable="dsamu_mj_lj_Eratio",
    xlabel=r"DSA Mu-type $E_{Matched Jet} / E_{LJ}$",
    target_bins=25,
    plot_label="Work in Progress",
    rebin_threshold=25,   
)
