# %%
# %pip install "numpy>=2.0,<2.3" --force-reinstall
# Out:
# Collecting numpy<2.3,>=2.0
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# python
import sys
import os
import importlib
# columnar analysis
from coffea import processor
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema
import awkward as ak
from dask.distributed import Client, performance_report
# local

sidm_path = str(os.getcwd()).split("/sidm")[0]
# sidm_path = str(sys.path[0]).split("/sidm")[0]
if sidm_path not in sys.path: sys.path.insert(1, sidm_path)
from sidm.tools import utilities, sidm_processor, scaleout, cutflow
from sidm.tools import llpnanoaodschema
# always reload local modules to pick up changes during development
importlib.reload(utilities)
importlib.reload(sidm_processor)
importlib.reload(scaleout)
# plotting
import matplotlib.pyplot as plt
utilities.set_plot_style()
# %matplotlib inline
from tqdm.notebook import tqdm
import coffea.util
import numpy as np
import mplhep as hep
import yaml
from sidm.tools.utilities import get_cut_yield, print_CR_yield, extract_cutflow_yields, plot_cutflow_panels
from pathlib import Path

# %%
# Load signal sample names from YAML files
yaml_file_path = "../../configs/ntuples/signal_2mu2e_v10.yaml"
with open(yaml_file_path, "r") as file:
    data = yaml.safe_load(file)

signals_2mu2e_all = list(
    data["llpNanoAOD_v2"]["samples"].keys()
)

yaml_file_path = "../../configs/ntuples/signal_4mu_v10.yaml"
with open(yaml_file_path, "r") as file:
    data = yaml.safe_load(file)

signals_4mu_all = list(
    data["llpNanoAOD_v2"]["samples"].keys()
)


# Combine all signal samples
signals_all = signals_2mu2e_all + signals_4mu_all


# Check whether an out dictionary already exists
try:
    out
    print(
        "The out dictionary already exists; "
        "will use what is saved in memory if possible"
    )
except NameError:
    print(
        "WARNING! No processor output stored in memory. "
        "Will load one coffea file for each sample."
    )
    out = {}

input_dir = Path("1LJ_CR_signal_full_merge")


# Load one merged coffea file for each signal point
for sample in signals_all:
    if sample in out:
        print(f"{sample} already found in memory; not loading file")
        continue

    input_file = input_dir / f"{sample}.coffea"
    print(f"Loading {input_file}")

    try:
        output = coffea.util.load(input_file)
    except FileNotFoundError:
        print(f"**** File not found: {input_file}")
        continue
    except Exception as error:
        print(f"**** Failed to load {input_file}: {error}")
        continue

    # Support the possible output structures:
    # output["out"][sample] or output[sample]
    if "out" in output and sample in output["out"]:
        out[sample] = output["out"][sample]
    elif sample in output:
        out[sample] = output[sample]
    else:
        print(
            f"**** Sample '{sample}' was not found inside "
            f"{input_file}"
        )
        print(f"Available top-level keys: {list(output.keys())}")
        continue

    print(f"Successfully loaded {sample}")
# Out:
# WARNING! No processor output stored in memory. Will load one coffea file for each sample.
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_0p25GeV_0p02mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_0p02mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_0p25GeV_0p2mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_0p2mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_0p25GeV_10p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_10p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_0p25GeV_20p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_0p25GeV_20p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_1p2GeV_0p096mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_0p096mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_1p2GeV_0p96mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_0p96mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_1p2GeV_48p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_48p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_1p2GeV_96p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_1p2GeV_96p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_5p0GeV_0p4mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_0p4mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_5p0GeV_4p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_4p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_5p0GeV_200mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_200mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_100GeV_5p0GeV_400mm.coffea
# Successfully loaded 2Mu2E_100GeV_5p0GeV_400mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_0p25GeV_0p013mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_0p013mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_0p25GeV_0p13mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_0p13mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_0p25GeV_1p3mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_1p3mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_0p25GeV_6p7mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_6p7mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_0p25GeV_13p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_0p25GeV_13p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_1p2GeV_0p064mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_0p064mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_1p2GeV_0p64mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_0p64mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_1p2GeV_6p4mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_6p4mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_1p2GeV_32p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_32p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_1p2GeV_64p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_1p2GeV_64p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_5p0GeV_0p27mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_0p27mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_5p0GeV_2p7mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_2p7mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_5p0GeV_27p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_27p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_5p0GeV_130p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_130p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_150GeV_5p0GeV_270p0mm.coffea
# Successfully loaded 2Mu2E_150GeV_5p0GeV_270p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_0p25GeV_0p01mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_0p01mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_0p25GeV_0p1mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_0p1mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_0p25GeV_1p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_1p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_0p25GeV_5p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_5p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_0p25GeV_10p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_0p25GeV_10p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_1p2GeV_0p048mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_0p048mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_1p2GeV_0p48mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_0p48mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_1p2GeV_4p8mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_4p8mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_1p2GeV_24p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_24p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_1p2GeV_48p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_1p2GeV_48p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_5p0GeV_0p2mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_0p2mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_5p0GeV_2p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_2p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_5p0GeV_20p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_20p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_5p0GeV_100p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_100p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_200GeV_5p0GeV_200p0mm.coffea
# Successfully loaded 2Mu2E_200GeV_5p0GeV_200p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_0p25GeV_0p004mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_0p004mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_0p25GeV_0p04mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_0p04mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_0p25GeV_0p4mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_0p4mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_0p25GeV_4p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_0p25GeV_4p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_1p2GeV_0p019mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_0p019mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_1p2GeV_0p19mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_0p19mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_1p2GeV_1p9mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_1p9mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_1p2GeV_19p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_1p2GeV_19p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_5p0GeV_0p08mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_0p08mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_5p0GeV_0p8mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_0p8mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_5p0GeV_8p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_8p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_500GeV_5p0GeV_80p0mm.coffea
# Successfully loaded 2Mu2E_500GeV_5p0GeV_80p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_0p25GeV_0p0025mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_0p0025mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_0p25GeV_0p025mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_0p025mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_0p25GeV_0p25mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_0p25mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_0p25GeV_1p2mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_1p2mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_0p25GeV_2p5mm.coffea
# Successfully loaded 2Mu2E_800GeV_0p25GeV_2p5mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_1p2GeV_0p012mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_0p012mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_1p2GeV_0p12mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_0p12mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_1p2GeV_1p2mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_1p2mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_1p2GeV_6p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_6p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_1p2GeV_12p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_1p2GeV_12p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_5p0GeV_0p05mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_0p05mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_5p0GeV_0p5mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_0p5mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_5p0GeV_5p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_5p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_5p0GeV_25p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_25p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_800GeV_5p0GeV_50p0mm.coffea
# Successfully loaded 2Mu2E_800GeV_5p0GeV_50p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_0p25GeV_0p002mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_0p002mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_0p25GeV_0p02mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_0p02mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_0p25GeV_0p2mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_0p2mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_0p25GeV_1p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_1p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_1p2GeV_0p0096mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_0p0096mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_1p2GeV_0p096mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_0p096mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_1p2GeV_0p96mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_0p96mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_1p2GeV_4p8mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_4p8mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 2Mu2E_1000GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_5p0GeV_0p04mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_0p04mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_5p0GeV_0p4mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_0p4mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_5p0GeV_4p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_4p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_5p0GeV_20p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_20p0mm
# Loading 1LJ_CR_signal_full_merge/2Mu2E_1000GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 2Mu2E_1000GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_0p25GeV_0p02mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_0p02mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_0p25GeV_0p2mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_0p2mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_0p25GeV_10p0mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_10p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_0p25GeV_20p0mm.coffea
# Successfully loaded 4Mu_100GeV_0p25GeV_20p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_1p2GeV_0p096mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_0p096mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_1p2GeV_0p96mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_0p96mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_1p2GeV_48p0mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_48p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_1p2GeV_96p0mm.coffea
# Successfully loaded 4Mu_100GeV_1p2GeV_96p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_5p0GeV_0p4mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_0p4mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_5p0GeV_4p0mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_4p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_5p0GeV_200mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_200mm
# Loading 1LJ_CR_signal_full_merge/4Mu_100GeV_5p0GeV_400mm.coffea
# Successfully loaded 4Mu_100GeV_5p0GeV_400mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_0p25GeV_0p013mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_0p013mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_0p25GeV_0p13mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_0p13mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_0p25GeV_1p3mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_1p3mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_0p25GeV_6p7mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_6p7mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_0p25GeV_13p0mm.coffea
# Successfully loaded 4Mu_150GeV_0p25GeV_13p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_1p2GeV_0p064mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_0p064mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_1p2GeV_0p64mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_0p64mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_1p2GeV_6p4mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_6p4mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_1p2GeV_32p0mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_32p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_1p2GeV_64p0mm.coffea
# Successfully loaded 4Mu_150GeV_1p2GeV_64p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_5p0GeV_0p27mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_0p27mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_5p0GeV_2p7mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_2p7mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_5p0GeV_27p0mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_27p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_5p0GeV_130p0mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_130p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_150GeV_5p0GeV_270p0mm.coffea
# Successfully loaded 4Mu_150GeV_5p0GeV_270p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_0p25GeV_0p01mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_0p01mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_0p25GeV_0p1mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_0p1mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_0p25GeV_1p0mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_1p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_0p25GeV_5p0mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_5p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_0p25GeV_10p0mm.coffea
# Successfully loaded 4Mu_200GeV_0p25GeV_10p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_1p2GeV_0p048mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_0p048mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_1p2GeV_0p48mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_0p48mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_1p2GeV_4p8mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_4p8mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_1p2GeV_24p0mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_24p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_1p2GeV_48p0mm.coffea
# Successfully loaded 4Mu_200GeV_1p2GeV_48p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_5p0GeV_0p2mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_0p2mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_5p0GeV_2p0mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_2p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_5p0GeV_20p0mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_20p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_5p0GeV_100p0mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_100p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_200GeV_5p0GeV_200p0mm.coffea
# Successfully loaded 4Mu_200GeV_5p0GeV_200p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_0p25GeV_0p004mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_0p004mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_0p25GeV_0p04mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_0p04mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_0p25GeV_0p4mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_0p4mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_0p25GeV_4p0mm.coffea
# Successfully loaded 4Mu_500GeV_0p25GeV_4p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_1p2GeV_0p019mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_0p019mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_1p2GeV_0p19mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_0p19mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_1p2GeV_1p9mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_1p9mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_1p2GeV_19p0mm.coffea
# Successfully loaded 4Mu_500GeV_1p2GeV_19p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_5p0GeV_0p08mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_0p08mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_5p0GeV_0p8mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_0p8mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_5p0GeV_8p0mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_8p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_40p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_500GeV_5p0GeV_80p0mm.coffea
# Successfully loaded 4Mu_500GeV_5p0GeV_80p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_0p25GeV_0p0025mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_0p0025mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_0p25GeV_0p025mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_0p025mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_0p25GeV_0p25mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_0p25mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_0p25GeV_1p2mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_1p2mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_0p25GeV_2p5mm.coffea
# Successfully loaded 4Mu_800GeV_0p25GeV_2p5mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_1p2GeV_0p012mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_0p012mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_1p2GeV_0p12mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_0p12mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_1p2GeV_1p2mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_1p2mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_1p2GeV_6p0mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_6p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_1p2GeV_12p0mm.coffea
# Successfully loaded 4Mu_800GeV_1p2GeV_12p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_5p0GeV_0p05mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_0p05mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_5p0GeV_0p5mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_0p5mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_5p0GeV_5p0mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_5p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_5p0GeV_25p0mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_25p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_800GeV_5p0GeV_50p0mm.coffea
# Successfully loaded 4Mu_800GeV_5p0GeV_50p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_0p25GeV_0p002mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_0p002mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_0p25GeV_0p02mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_0p02mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_0p25GeV_0p2mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_0p2mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_0p25GeV_1p0mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_1p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_0p25GeV_2p0mm.coffea
# Successfully loaded 4Mu_1000GeV_0p25GeV_2p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_1p2GeV_0p0096mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_0p0096mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_1p2GeV_0p096mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_0p096mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_1p2GeV_0p96mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_0p96mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_1p2GeV_4p8mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_4p8mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_1p2GeV_9p6mm.coffea
# Successfully loaded 4Mu_1000GeV_1p2GeV_9p6mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_5p0GeV_0p04mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_0p04mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_5p0GeV_0p4mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_0p4mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_5p0GeV_4p0mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_4p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_5p0GeV_20p0mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_20p0mm
# Loading 1LJ_CR_signal_full_merge/4Mu_1000GeV_5p0GeV_40p0mm.coffea
# Successfully loaded 4Mu_1000GeV_5p0GeV_40p0mm

# %%
samples_bkg = [
    "TTJets",
    "QCD_Pt15To20",
    "QCD_Pt20To30",
    "QCD_Pt30To50",
    "QCD_Pt50To80",
    "QCD_Pt80To120", 
    "QCD_Pt120To170",
    "QCD_Pt170To300", 
    "QCD_Pt300To470",
    "QCD_Pt470To600", 
    "QCD_Pt600To800", 
    "QCD_Pt800To1000",
    "QCD_Pt1000", 
    "DYJetsToLL_M10to50",
    "DYJetsToLL_M50", 
    "WW",
    "WZ",
    "ZZ",
]

# %%
#First check if there is already an out dictionary
try:
    out
    print("The _out_ dictionary already exists; will use what is saved in memory if possible")
except NameError:
    print("WARNING! No processor output stored in the kernel's memory. Will try to load pickled coffea file for each sample instead")
    out = {}

#For each sample, try to use the data in memory if possible; if not try to load the file
#If those both fail, then raise an error and skip it
for sample in samples_bkg:
    if sample in out:
        print(f"{sample} already found in memory; not loading file")
    else:
        print(f"Loading file for sample {sample}")
        filename = sample + ".coffea"
        try: 
            output = coffea.util.load("1LJ_CR_bkg_full_merge/"+filename)
            print("Successfully opened file")        
            out[sample] = output["out"][sample]
            # out[sample] = output["out"][sample.removesuffix("_part1")]
        except Exception:
            out[sample] = output[sample]
            # print("**** ERROR! File not found. Check the file name, or run the processor again and save the output to a pickle file using coffea.util.save")
# Out:
# The _out_ dictionary already exists; will use what is saved in memory if possible
# Loading file for sample TTJets
# Successfully opened file
# Loading file for sample QCD_Pt15To20
# Successfully opened file
# Loading file for sample QCD_Pt20To30
# Successfully opened file
# Loading file for sample QCD_Pt30To50
# Successfully opened file
# Loading file for sample QCD_Pt50To80
# Successfully opened file
# Loading file for sample QCD_Pt80To120
# Successfully opened file
# Loading file for sample QCD_Pt120To170
# Successfully opened file
# Loading file for sample QCD_Pt170To300
# Successfully opened file
# Loading file for sample QCD_Pt300To470
# Successfully opened file
# Loading file for sample QCD_Pt470To600
# Successfully opened file
# Loading file for sample QCD_Pt600To800
# Successfully opened file
# Loading file for sample QCD_Pt800To1000
# Successfully opened file
# Loading file for sample QCD_Pt1000
# Successfully opened file
# Loading file for sample DYJetsToLL_M10to50
# Successfully opened file
# Loading file for sample DYJetsToLL_M50
# Successfully opened file
# Loading file for sample WW
# Successfully opened file
# Loading file for sample WZ
# Successfully opened file
# Loading file for sample ZZ
# Successfully opened file

# %%
channels = [
    "data_control_region_1muLj", "data_control_region_1egmLj"
]

# %%
result = print_CR_yield(
    out,
    signals_2mu2e_all,
    samples_bkg,
    cut_name="= 1 muLJs",
    channel=channels[0],
    weighted=True,
    cumulative=True,
)
# Out:
# === Signal yields ===
# 2Mu2E_100GeV_0p25GeV_0p02mm         : 1.302535
# 2Mu2E_100GeV_0p25GeV_0p2mm          : 1.603726
# 2Mu2E_100GeV_0p25GeV_2p0mm          : 1.751358
# 2Mu2E_100GeV_0p25GeV_10p0mm         : 2.179423
# 2Mu2E_100GeV_0p25GeV_20p0mm         : 2.102322
# 2Mu2E_100GeV_1p2GeV_0p096mm         : 1.238269
# 2Mu2E_100GeV_1p2GeV_0p96mm          : 1.400239
# 2Mu2E_100GeV_1p2GeV_9p6mm           : 1.411755
# 2Mu2E_100GeV_1p2GeV_48p0mm          : 1.454030
# 2Mu2E_100GeV_1p2GeV_96p0mm          : 1.361987
# 2Mu2E_100GeV_5p0GeV_0p4mm           : 0.980955
# 2Mu2E_100GeV_5p0GeV_4p0mm           : 1.184170
# 2Mu2E_100GeV_5p0GeV_40p0mm          : 1.541863
# 2Mu2E_100GeV_5p0GeV_200mm           : 1.655983
# 2Mu2E_100GeV_5p0GeV_400mm           : 1.570290
# 2Mu2E_150GeV_0p25GeV_0p013mm        : 1.470125
# 2Mu2E_150GeV_0p25GeV_0p13mm         : 2.216032
# 2Mu2E_150GeV_0p25GeV_1p3mm          : 3.662922
# 2Mu2E_150GeV_0p25GeV_6p7mm          : 5.418060
# 2Mu2E_150GeV_0p25GeV_13p0mm         : 5.479722
# 2Mu2E_150GeV_1p2GeV_0p064mm         : 1.333828
# 2Mu2E_150GeV_1p2GeV_0p64mm          : 1.859239
# 2Mu2E_150GeV_1p2GeV_6p4mm           : 2.364232
# 2Mu2E_150GeV_1p2GeV_32p0mm          : 3.160021
# 2Mu2E_150GeV_1p2GeV_64p0mm          : 3.189377
# 2Mu2E_150GeV_5p0GeV_0p27mm          : 0.696827
# 2Mu2E_150GeV_5p0GeV_2p7mm           : 1.068012
# 2Mu2E_150GeV_5p0GeV_27p0mm          : 1.759576
# 2Mu2E_150GeV_5p0GeV_130p0mm         : 3.159031
# 2Mu2E_150GeV_5p0GeV_270p0mm         : 3.340765
# 2Mu2E_200GeV_0p25GeV_0p01mm         : 1.750013
# 2Mu2E_200GeV_0p25GeV_0p1mm          : 2.878926
# 2Mu2E_200GeV_0p25GeV_1p0mm          : 4.647558
# 2Mu2E_200GeV_0p25GeV_5p0mm          : 6.821458
# 2Mu2E_200GeV_0p25GeV_10p0mm         : 7.155068
# 2Mu2E_200GeV_1p2GeV_0p048mm         : 1.543220
# 2Mu2E_200GeV_1p2GeV_0p48mm          : 2.296652
# 2Mu2E_200GeV_1p2GeV_4p8mm           : 3.112055
# 2Mu2E_200GeV_1p2GeV_24p0mm          : 4.110376
# 2Mu2E_200GeV_1p2GeV_48p0mm          : 4.225404
# 2Mu2E_200GeV_5p0GeV_0p2mm           : 0.647111
# 2Mu2E_200GeV_5p0GeV_2p0mm           : 1.144361
# 2Mu2E_200GeV_5p0GeV_20p0mm          : 2.067479
# 2Mu2E_200GeV_5p0GeV_100p0mm         : 3.807863
# 2Mu2E_200GeV_5p0GeV_200p0mm         : 4.161643
# 2Mu2E_500GeV_0p25GeV_0p004mm        : 1.667660
# 2Mu2E_500GeV_0p25GeV_0p04mm         : 2.444210
# 2Mu2E_500GeV_0p25GeV_0p4mm          : 3.768851
# 2Mu2E_500GeV_0p25GeV_2p0mm          : 4.873992
# 2Mu2E_500GeV_0p25GeV_4p0mm          : 4.728854
# 2Mu2E_500GeV_1p2GeV_0p019mm         : 1.667179
# 2Mu2E_500GeV_1p2GeV_0p19mm          : 2.508310
# 2Mu2E_500GeV_1p2GeV_1p9mm           : 3.355414
# 2Mu2E_500GeV_1p2GeV_9p6mm           : 4.180423
# 2Mu2E_500GeV_1p2GeV_19p0mm          : 4.125850
# 2Mu2E_500GeV_5p0GeV_0p08mm          : 1.286980
# 2Mu2E_500GeV_5p0GeV_0p8mm           : 1.806225
# 2Mu2E_500GeV_5p0GeV_8p0mm           : 2.566548
# 2Mu2E_500GeV_5p0GeV_40p0mm          : 3.776124
# 2Mu2E_500GeV_5p0GeV_80p0mm          : 4.008054
# 2Mu2E_800GeV_0p25GeV_0p0025mm       : 1.243524
# 2Mu2E_800GeV_0p25GeV_0p025mm        : 1.670739
# 2Mu2E_800GeV_0p25GeV_0p25mm         : 2.425377
# 2Mu2E_800GeV_0p25GeV_1p2mm          : 2.557272
# 2Mu2E_800GeV_0p25GeV_2p5mm          : 2.412990
# 2Mu2E_800GeV_1p2GeV_0p012mm         : 1.393409
# 2Mu2E_800GeV_1p2GeV_0p12mm          : 2.008138
# 2Mu2E_800GeV_1p2GeV_1p2mm           : 2.745039
# 2Mu2E_800GeV_1p2GeV_6p0mm           : 3.134724
# 2Mu2E_800GeV_1p2GeV_12p0mm          : 3.029472
# 2Mu2E_800GeV_5p0GeV_0p05mm          : 1.805196
# 2Mu2E_800GeV_5p0GeV_0p5mm           : 2.453328
# 2Mu2E_800GeV_5p0GeV_5p0mm           : 2.682161
# 2Mu2E_800GeV_5p0GeV_25p0mm          : 3.219956
# 2Mu2E_800GeV_5p0GeV_50p0mm          : 3.186323
# 2Mu2E_1000GeV_0p25GeV_0p002mm       : 0.867817
# 2Mu2E_1000GeV_0p25GeV_0p02mm        : 1.274481
# 2Mu2E_1000GeV_0p25GeV_0p2mm         : 1.666496
# 2Mu2E_1000GeV_0p25GeV_1p0mm         : 1.708674
# 2Mu2E_1000GeV_0p25GeV_2p0mm         : 1.491726
# 2Mu2E_1000GeV_1p2GeV_0p0096mm       : 1.235398
# 2Mu2E_1000GeV_1p2GeV_0p096mm        : 1.769025
# 2Mu2E_1000GeV_1p2GeV_0p96mm         : 2.388145
# 2Mu2E_1000GeV_1p2GeV_4p8mm          : 2.573875
# 2Mu2E_1000GeV_1p2GeV_9p6mm          : 2.422456
# 2Mu2E_1000GeV_5p0GeV_0p04mm         : 1.890272
# 2Mu2E_1000GeV_5p0GeV_0p4mm          : 2.400320
# 2Mu2E_1000GeV_5p0GeV_4p0mm          : 2.482500
# 2Mu2E_1000GeV_5p0GeV_20p0mm         : 2.784907
# 2Mu2E_1000GeV_5p0GeV_40p0mm         : 2.675467
#
# === Background yields ===
# TTJets                              : 18385.286890
# QCD_Pt15To20                        : 187126.714074
# QCD_Pt20To30                        : 585583.802917
# QCD_Pt30To50                        : 1532871.333239
# QCD_Pt50To80                        : 2424032.949605
# QCD_Pt80To120                       : 2357759.113125
# QCD_Pt120To170                      : 1374685.069492
# QCD_Pt170To300                      : 927565.830618
# QCD_Pt300To470                      : 162781.293029
# QCD_Pt470To600                      : 22004.441818
# QCD_Pt600To800                      : 7914.308990
# QCD_Pt800To1000                     : 1676.887658
# QCD_Pt1000                          : 621.215076
# DYJetsToLL_M10to50                  : 50113.768650
# DYJetsToLL_M50                      : 27786.978196
# WW                                  : 236.045643
# WZ                                  : 101.288271
# ZZ                                  : 160.961789
#
# === Totals ===
# S = 225.649739
# B = 9681407.289079
# S/(S+B) = 2.330699e-05

# %%
result = print_CR_yield(
    out,
    signals_4mu_all,
    samples_bkg,
    cut_name="= 1 muLJs",
    channel=channels[0],
    weighted=True,
    cumulative=True,
)
# Out:
# === Signal yields ===
# 4Mu_100GeV_0p25GeV_0p02mm           : 2.357051
# 4Mu_100GeV_0p25GeV_0p2mm            : 2.747241
# 4Mu_100GeV_0p25GeV_2p0mm            : 6.829755
# 4Mu_100GeV_0p25GeV_10p0mm           : 11.024212
# 4Mu_100GeV_0p25GeV_20p0mm           : 10.228926
# 4Mu_100GeV_1p2GeV_0p096mm           : 2.108775
# 4Mu_100GeV_1p2GeV_0p96mm            : 2.294897
# 4Mu_100GeV_1p2GeV_9p6mm             : 6.032534
# 4Mu_100GeV_1p2GeV_48p0mm            : 9.083073
# 4Mu_100GeV_1p2GeV_96p0mm            : 8.237295
# 4Mu_100GeV_5p0GeV_0p4mm             : 2.253942
# 4Mu_100GeV_5p0GeV_4p0mm             : 2.625285
# 4Mu_100GeV_5p0GeV_40p0mm            : 6.847772
# 4Mu_100GeV_5p0GeV_200mm             : 9.130706
# 4Mu_100GeV_5p0GeV_400mm             : 7.943447
# 4Mu_150GeV_0p25GeV_0p013mm          : 1.245933
# 4Mu_150GeV_0p25GeV_0p13mm           : 1.680586
# 4Mu_150GeV_0p25GeV_1p3mm            : 6.590187
# 4Mu_150GeV_0p25GeV_6p7mm            : 14.174226
# 4Mu_150GeV_0p25GeV_13p0mm           : 13.994274
# 4Mu_150GeV_1p2GeV_0p064mm           : 0.789178
# 4Mu_150GeV_1p2GeV_0p64mm            : 1.002676
# 4Mu_150GeV_1p2GeV_6p4mm             : 5.240675
# 4Mu_150GeV_1p2GeV_32p0mm            : 10.760755
# 4Mu_150GeV_1p2GeV_64p0mm            : 10.348549
# 4Mu_150GeV_5p0GeV_0p27mm            : 0.804532
# 4Mu_150GeV_5p0GeV_2p7mm             : 1.010497
# 4Mu_150GeV_5p0GeV_27p0mm            : 5.803850
# 4Mu_150GeV_5p0GeV_130p0mm           : 9.894503
# 4Mu_150GeV_5p0GeV_270p0mm           : 9.790783
# 4Mu_200GeV_0p25GeV_0p01mm           : 0.784691
# 4Mu_200GeV_0p25GeV_0p1mm            : 1.079915
# 4Mu_200GeV_0p25GeV_1p0mm            : 6.066028
# 4Mu_200GeV_0p25GeV_5p0mm            : 14.400548
# 4Mu_200GeV_0p25GeV_10p0mm           : 14.624212
# 4Mu_200GeV_1p2GeV_0p048mm           : 0.475064
# 4Mu_200GeV_1p2GeV_0p48mm            : 0.668137
# 4Mu_200GeV_1p2GeV_4p8mm             : 5.284571
# 4Mu_200GeV_1p2GeV_24p0mm            : 11.529768
# 4Mu_200GeV_1p2GeV_48p0mm            : 11.223416
# 4Mu_200GeV_5p0GeV_0p2mm             : 0.489639
# 4Mu_200GeV_5p0GeV_2p0mm             : 0.647275
# 4Mu_200GeV_5p0GeV_20p0mm            : 5.413698
# 4Mu_200GeV_5p0GeV_100p0mm           : 10.289363
# 4Mu_200GeV_5p0GeV_200p0mm           : 10.382119
# 4Mu_500GeV_0p25GeV_0p004mm          : 0.171686
# 4Mu_500GeV_0p25GeV_0p04mm           : 0.274829
# 4Mu_500GeV_0p25GeV_0p4mm            : 5.025494
# 4Mu_500GeV_0p25GeV_2p0mm            : 11.118605
# 4Mu_500GeV_0p25GeV_4p0mm            : 10.235274
# 4Mu_500GeV_1p2GeV_0p019mm           : 0.259219
# 4Mu_500GeV_1p2GeV_0p19mm            : 0.520138
# 4Mu_500GeV_1p2GeV_1p9mm             : 5.650809
# 4Mu_500GeV_1p2GeV_9p6mm             : 11.718070
# 4Mu_500GeV_1p2GeV_19p0mm            : 10.739888
# 4Mu_500GeV_5p0GeV_0p08mm            : 0.205762
# 4Mu_500GeV_5p0GeV_0p8mm             : 0.331736
# 4Mu_500GeV_5p0GeV_8p0mm             : 4.913604
# 4Mu_500GeV_5p0GeV_40p0mm            : 9.994289
# 4Mu_500GeV_5p0GeV_80p0mm            : 9.669787
# 4Mu_800GeV_0p25GeV_0p0025mm         : 0.245789
# 4Mu_800GeV_0p25GeV_0p025mm          : 0.391682
# 4Mu_800GeV_0p25GeV_0p25mm           : 4.967605
# 4Mu_800GeV_0p25GeV_1p2mm            : 7.961420
# 4Mu_800GeV_0p25GeV_2p5mm            : 6.533749
# 4Mu_800GeV_1p2GeV_0p012mm           : 0.332979
# 4Mu_800GeV_1p2GeV_0p12mm            : 0.572070
# 4Mu_800GeV_1p2GeV_1p2mm             : 5.888318
# 4Mu_800GeV_1p2GeV_6p0mm             : 10.210469
# 4Mu_800GeV_1p2GeV_12p0mm            : 8.770108
# 4Mu_800GeV_5p0GeV_0p05mm            : 0.279174
# 4Mu_800GeV_5p0GeV_0p5mm             : 0.375183
# 4Mu_800GeV_5p0GeV_5p0mm             : 5.017644
# 4Mu_800GeV_5p0GeV_25p0mm            : 9.388139
# 4Mu_800GeV_5p0GeV_50p0mm            : 8.493787
# 4Mu_1000GeV_0p25GeV_0p002mm         : 0.316071
# 4Mu_1000GeV_0p25GeV_0p02mm          : 0.470161
# 4Mu_1000GeV_0p25GeV_0p2mm           : 4.407387
# 4Mu_1000GeV_0p25GeV_1p0mm           : 6.092842
# 4Mu_1000GeV_0p25GeV_2p0mm           : 4.918165
# 4Mu_1000GeV_1p2GeV_0p0096mm         : 0.379551
# 4Mu_1000GeV_1p2GeV_0p096mm          : 0.642588
# 4Mu_1000GeV_1p2GeV_0p96mm           : 5.819204
# 4Mu_1000GeV_1p2GeV_4p8mm            : 9.143385
# 4Mu_1000GeV_1p2GeV_9p6mm            : 7.541561
# 4Mu_1000GeV_5p0GeV_0p04mm           : 0.310130
# 4Mu_1000GeV_5p0GeV_0p4mm            : 0.419988
# 4Mu_1000GeV_5p0GeV_4p0mm            : 4.987936
# 4Mu_1000GeV_5p0GeV_20p0mm           : 8.768421
# 4Mu_1000GeV_5p0GeV_40p0mm           : 7.712844
#
# === Background yields ===
# TTJets                              : 18385.286890
# QCD_Pt15To20                        : 187126.714074
# QCD_Pt20To30                        : 585583.802917
# QCD_Pt30To50                        : 1532871.333239
# QCD_Pt50To80                        : 2424032.949605
# QCD_Pt80To120                       : 2357759.113125
# QCD_Pt120To170                      : 1374685.069492
# QCD_Pt170To300                      : 927565.830618
# QCD_Pt300To470                      : 162781.293029
# QCD_Pt470To600                      : 22004.441818
# QCD_Pt600To800                      : 7914.308990
# QCD_Pt800To1000                     : 1676.887658
# QCD_Pt1000                          : 621.215076
# DYJetsToLL_M10to50                  : 50113.768650
# DYJetsToLL_M50                      : 27786.978196
# WW                                  : 236.045643
# WZ                                  : 101.288271
# ZZ                                  : 160.961789
#
# === Totals ===
# S = 488.422097
# B = 9681407.289079
# S/(S+B) = 5.044695e-05

# %%
group1_2mu2e = [
    "2Mu2E_100GeV_0p25GeV_0p02mm",
    "2Mu2E_100GeV_0p25GeV_20p0mm",
    "2Mu2E_100GeV_1p2GeV_0p096mm",
    "2Mu2E_100GeV_1p2GeV_96p0mm",
    "2Mu2E_100GeV_5p0GeV_0p4mm",
    "2Mu2E_100GeV_5p0GeV_400mm",
]

group2_2mu2e = [
    "2Mu2E_150GeV_0p25GeV_0p013mm",
    "2Mu2E_150GeV_0p25GeV_13p0mm",
    "2Mu2E_150GeV_1p2GeV_0p064mm",
    "2Mu2E_150GeV_1p2GeV_64p0mm",
    "2Mu2E_150GeV_5p0GeV_0p27mm",
    "2Mu2E_150GeV_5p0GeV_270p0mm",
]

group3_2mu2e = [
    "2Mu2E_200GeV_0p25GeV_0p01mm",
    "2Mu2E_200GeV_0p25GeV_10p0mm",
    "2Mu2E_200GeV_1p2GeV_0p048mm",
    "2Mu2E_200GeV_1p2GeV_48p0mm",
    "2Mu2E_200GeV_5p0GeV_0p2mm",
    "2Mu2E_200GeV_5p0GeV_200p0mm",
]

group4_2mu2e = [
    "2Mu2E_500GeV_0p25GeV_0p004mm",
    "2Mu2E_500GeV_0p25GeV_4p0mm",
    "2Mu2E_500GeV_1p2GeV_0p019mm",
    "2Mu2E_500GeV_1p2GeV_19p0mm",
    "2Mu2E_500GeV_5p0GeV_0p08mm",
    "2Mu2E_500GeV_5p0GeV_80p0mm",
]

group5_2mu2e = [
    "2Mu2E_800GeV_0p25GeV_0p0025mm",
    "2Mu2E_800GeV_0p25GeV_2p5mm",
    "2Mu2E_800GeV_1p2GeV_0p012mm",
    "2Mu2E_800GeV_1p2GeV_12p0mm",
    "2Mu2E_800GeV_5p0GeV_0p05mm",
    "2Mu2E_800GeV_5p0GeV_50p0mm",
]

group6_2mu2e = [
    "2Mu2E_1000GeV_0p25GeV_0p002mm",
    "2Mu2E_1000GeV_0p25GeV_2p0mm",
    "2Mu2E_1000GeV_1p2GeV_0p0096mm",
    "2Mu2E_1000GeV_1p2GeV_9p6mm",
    "2Mu2E_1000GeV_5p0GeV_0p04mm",
    "2Mu2E_1000GeV_5p0GeV_40p0mm",
]

# %%
group1_4mu = [
    "4Mu_100GeV_0p25GeV_0p02mm",
    "4Mu_100GeV_0p25GeV_20p0mm",
    "4Mu_100GeV_1p2GeV_0p096mm",
    "4Mu_100GeV_1p2GeV_96p0mm",
    "4Mu_100GeV_5p0GeV_0p4mm",
    "4Mu_100GeV_5p0GeV_400mm",
]

group2_4mu = [
    "4Mu_150GeV_0p25GeV_0p013mm",
    "4Mu_150GeV_0p25GeV_13p0mm",
    "4Mu_150GeV_1p2GeV_0p064mm",
    "4Mu_150GeV_1p2GeV_64p0mm",
    "4Mu_150GeV_5p0GeV_0p27mm",
    "4Mu_150GeV_5p0GeV_270p0mm",
]

group3_4mu = [
    "4Mu_200GeV_0p25GeV_0p01mm",
    "4Mu_200GeV_0p25GeV_10p0mm",
    "4Mu_200GeV_1p2GeV_0p048mm",
    "4Mu_200GeV_1p2GeV_48p0mm",
    "4Mu_200GeV_5p0GeV_0p2mm",
    "4Mu_200GeV_5p0GeV_200p0mm",
]

group4_4mu = [
    "4Mu_500GeV_0p25GeV_0p004mm",
    "4Mu_500GeV_0p25GeV_4p0mm",
    "4Mu_500GeV_1p2GeV_0p019mm",
    "4Mu_500GeV_1p2GeV_19p0mm",
    "4Mu_500GeV_5p0GeV_0p08mm",
    "4Mu_500GeV_5p0GeV_80p0mm",
]

group5_4mu = [
    "4Mu_800GeV_0p25GeV_0p0025mm",
    "4Mu_800GeV_0p25GeV_2p5mm",
    "4Mu_800GeV_1p2GeV_0p012mm",
    "4Mu_800GeV_1p2GeV_12p0mm",
    "4Mu_800GeV_5p0GeV_0p05mm",
    "4Mu_800GeV_5p0GeV_50p0mm",
]

group6_4mu = [
    "4Mu_1000GeV_0p25GeV_0p002mm",
    "4Mu_1000GeV_0p25GeV_2p0mm",
    "4Mu_1000GeV_1p2GeV_0p0096mm",
    "4Mu_1000GeV_1p2GeV_9p6mm",
    "4Mu_1000GeV_5p0GeV_0p04mm",
    "4Mu_1000GeV_5p0GeV_40p0mm",
]

# %%
QCD = [
    "QCD_Pt15To20",
    "QCD_Pt20To30",
    "QCD_Pt30To50",
    "QCD_Pt50To80",
    "QCD_Pt80To120",
    "QCD_Pt120To170",
    "QCD_Pt170To300",
    "QCD_Pt300To470",
    "QCD_Pt470To600",
    "QCD_Pt600To800",
    "QCD_Pt800To1000",
    "QCD_Pt1000",
]

DY = [
    "DYJetsToLL_M10to50",
    "DYJetsToLL_M50",
]

TT = ["TTJets"]

WW = ["WW"]

WZ = ["WZ"]

ZZ = ["ZZ"]

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        group1_2mu2e,
        group2_2mu2e,
        group3_2mu2e,
        group4_2mu2e,
        group5_2mu2e,
        group6_2mu2e,
    ],
    channel=channels[0],
    titles=[
        "2Mu2E 100 GeV",
        "2Mu2E 150 GeV",
        "2Mu2E 200 GeV",
        "2Mu2E 500 GeV",
        "2Mu2E 800 GeV",
        "2Mu2E 1000 GeV",
    ],
    unweighted=False,
    cumulative=True,
    normalize=False,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        group1_2mu2e,
        group2_2mu2e,
        group3_2mu2e,
        group4_2mu2e,
        group5_2mu2e,
        group6_2mu2e,
    ],
    channel=channels[0],
    titles=[
        "2Mu2E 100 GeV",
        "2Mu2E 150 GeV",
        "2Mu2E 200 GeV",
        "2Mu2E 500 GeV",
        "2Mu2E 800 GeV",
        "2Mu2E 1000 GeV",
    ],
    unweighted=False,
    cumulative=True,
    normalize=True,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        group1_4mu,
        group2_4mu,
        group3_4mu,
        group4_4mu,
        group5_4mu,
        group6_4mu,
    ],
    channel=channels[0],
    titles=[
        "4Mu 100 GeV",
        "4Mu 150 GeV",
        "4Mu 200 GeV",
        "4Mu 500 GeV",
        "4Mu 800 GeV",
        "4Mu 1000 GeV",
    ],
    unweighted=False,
    cumulative=True,
    normalize=False,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        group1_4mu,
        group2_4mu,
        group3_4mu,
        group4_4mu,
        group5_4mu,
        group6_4mu,
    ],
    channel=channels[0],
    titles=[
        "4Mu 100 GeV",
        "4Mu 150 GeV",
        "4Mu 200 GeV",
        "4Mu 500 GeV",
        "4Mu 800 GeV",
        "4Mu 1000 GeV",
    ],
    unweighted=False,
    cumulative=True,
    normalize=True,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        QCD,
        DY,
        TT,
        WW,
        WZ,
        ZZ,
    ],
    channel=channels[0],
    titles=[
        "QCD",
        "DY",
        "TT",
        "WW",
        "WZ",
        "ZZ",
    ],
    unweighted=False,
    cumulative=True,
    normalize=False,
    logy=True,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        QCD,
        DY,
        TT,
        WW,
        WZ,
        ZZ,
    ],
    channel=channels[0],
    titles=[
        "QCD",
        "DY",
        "TT",
        "WW",
        "WZ",
        "ZZ",
    ],
    unweighted=False,
    cumulative=True,
    normalize=True,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)
