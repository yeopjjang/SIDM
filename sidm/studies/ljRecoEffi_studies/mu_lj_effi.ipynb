# %%
# python
import sys
import importlib
# columnar analysis
from coffea import processor
from coffea.nanoevents import NanoAODSchema
import awkward as ak
from dask.distributed import Client, performance_report
# local
sidm_path = str(sys.path[0]).split("/sidm")[0]
if sidm_path not in sys.path: sys.path.insert(1, sidm_path)
from sidm.tools import utilities, sidm_processor, scaleout
# always reload local modules to pick up changes during development
importlib.reload(utilities)
importlib.reload(sidm_processor)
importlib.reload(scaleout)
import matplotlib.pyplot as plt
utilities.set_plot_style()
# %matplotlib inline
import mplhep as hep

# %%
client = scaleout.make_dask_client("tls://localhost:8786")
client
# Out:
# <Client: 'tls://192.168.197.238:8786' processes=0 threads=0, memory=0 B>

# %%
samples = [
    #"2Mu2E_100GeV_5GeV_400mm",
    #"2Mu2E_100GeV_5GeV_400mm",
    #"2Mu2E_150GeV_5GeV_2p7mm",
    "2Mu2E_200GeV_0p25GeV_10p0mm",
    "2Mu2E_200GeV_1p2GeV_48p0mm",
     "2Mu2E_200GeV_5p0GeV_200p0mm",
    "2Mu2E_1000GeV_0p25GeV_2p0mm",
    "2Mu2E_1000GeV_5p0GeV_40p0mm"
    #"2Mu2E_500GeV_5GeV_80mm",
    #"2Mu2E_800GeV_5GeV_0p5mm",
    #"2Mu2E_1000GeV_5GeV_0p4mm",
    #"2Mu2E_1000GeV_5GeV_0p04mm",
    #"2Mu2E_1000GeV_5GeV_20mm",
    #"2Mu2E_100GeV_1p2GeV_9p6mm",
    #"2Mu2E_1000GeV_5GeV_40mm",
    #"2Mu2E_100GeV_p25GeV_400mm",
   # "2Mu2E_1000GeV_5GeV_4mm",
    
]
fileset = utilities.make_fileset(samples, 
                                 "llpNanoAOD_v2", 
                                 location_cfg="signal_2mu2e_v10.yaml",
                                 # max_files =10
                                 # max_files =1
                                )

# %%
channels = [
    # "baseNoLj", 
           "baseNoLj_A_mumu_matched_lj_highPT_lowLxyA",
            "baseNoLj_A_mumu_highPtA_lowLxyA",
        
           ]
p = sidm_processor.SidmProcessor(
    channels,
    ["gen_base"],
    lj_reco_choices=["0.4"],
   
)
runner = processor.Runner(
    #executor=processor.IterativeExecutor(),
    executor=processor.DaskExecutor(client=client),
    schema=NanoAODSchema,
    #maxchunks=1,
    #skipbadfiles=True,
    savemetrics=True,
)
# test if processor is serializable
import coffea.util as coffea_util
coffea_util.save(p, "processor.coffea")
print(coffea_util.load("processor.coffea"))
with performance_report(filename="dask-report.html"):
    output = runner.run(fileset, treename="Events", processor_instance=p)
# Out:
# <sidm.tools.sidm_processor.SidmProcessor object at 0x7ef80f6f33d0>
# [                                        ] | 0% Completed |  0.1s
# /opt/conda/lib/python3.9/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 12.0.0. Please consider upgrading.
#   warnings.warn(
# [########################################] | 100% Completed |  2min 37.7s

# %%
ch2 = "baseNoLj_A_mumu_matched_lj_highPT_lowLxyA"
ch1 = "baseNoLj_A_mumu_highPtA_lowLxyA"

# %%
hists = output["out"]["2Mu2E_200GeV_0p25GeV_10p0mm"]["hists"]
utilities.plot_ratio (hists["genAs_toMu_pt"][ch2, ::3j],
           hists["genAs_toMu_pt"][ch1, ::3j], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genAs_toMu_lxy"][ch2, ::2j],
           hists["genAs_toMu_lxy"][ch1, ::2j], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genMu_genMu_dR_XXLowRange"][ch2, ::2j],
           hists["genMu_genMu_dR_XXLowRange"][ch1, ::2j], 
          legend = [ch2, ch1])
# Out:
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals

# %%
hists = output["out"]["2Mu2E_200GeV_1p2GeV_48p0mm"]["hists"]
utilities.plot_ratio (hists["genAs_toMu_pt"][ch2, ::3j],
           hists["genAs_toMu_pt"][ch1, ::3j], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genAs_toMu_lxy"][ch2, ::2j],
           hists["genAs_toMu_lxy"][ch1, ::2j], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genMu_genMu_dR_XLowRange"][ch2, ::2j],
           hists["genMu_genMu_dR_XLowRange"][ch1, ::2j], 
          legend = [ch2, ch1])
# Out:
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals

# %%
hists = output["out"]["2Mu2E_200GeV_5p0GeV_200p0mm"]["hists"]
utilities.plot_ratio (hists["genAs_toMu_pt"][ch2, ::3j],
           hists["genAs_toMu_pt"][ch1, ::3j], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genAs_toMu_lxy"][ch2, ::2j],
           hists["genAs_toMu_lxy"][ch1, ::2j], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genMu_genMu_dR_lowRange"][ch2, ::2j],
           hists["genMu_genMu_dR_lowRange"][ch1, ::2j], 
          legend = [ch2, ch1])
# Out:
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals

# %%
hists = output["out"]["2Mu2E_1000GeV_0p25GeV_2p0mm"]["hists"]
utilities.plot_ratio (hists["genAs_toMu_pt_highRange"][ch2, ::3j],
           hists["genAs_toMu_pt_highRange"][ch1, ::3j], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genAs_toMu_lxy"][ch2, :],
           hists["genAs_toMu_lxy"][ch1, :], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genMu_genMu_dR_XXLowRange"][ch2, ::2j],
           hists["genMu_genMu_dR_XXLowRange"][ch1, ::2j], 
          legend = [ch2, ch1])
# Out:
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals

# %%
hists = output["out"]["2Mu2E_1000GeV_5p0GeV_40p0mm"]["hists"]
utilities.plot_ratio (hists["genAs_toMu_pt_highRange"][ch2, ::3j],
           hists["genAs_toMu_pt_highRange"][ch1, ::3j], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genAs_toMu_lxy"][ch2, :],
           hists["genAs_toMu_lxy"][ch1, :], 
          legend = [ch2, ch1])
utilities.plot_ratio (hists["genMu_genMu_dR_lowRange"][ch2, ::2j],
           hists["genMu_genMu_dR_lowRange"][ch1, ::2j], 
          legend = [ch2, ch1])
# Out:
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /home/cms-jovyan/SIDM/sidm/tools/utilities.py:142: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
